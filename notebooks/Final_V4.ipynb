# %%
# ================================================================
# SEL 0 -- Instalasi Dependensi & Import Library
# ================================================================
# !pip install -q kagglehub transformers datasets accelerate sentencepiece scikit-learn seaborn

import gc
import json as _json
import os
import random
import shutil
import warnings
from pathlib import Path
from dataclasses import dataclass
from typing import Any, Dict, List, Tuple

warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.utils import resample
from sklearn.metrics import (
    accuracy_score,
    precision_recall_fscore_support,
    classification_report,
    confusion_matrix,
    f1_score,
    roc_curve,
    auc,
    precision_score,
    recall_score,
)

import torch
import transformers
import kagglehub
from datasets import Dataset
from transformers import (
    AutoTokenizer,
    AutoModelForSequenceClassification,
    DataCollatorWithPadding,
    TrainingArguments,
    Trainer,
    set_seed,
)

print("Semua library berhasil di-import.")
print(f"   PyTorch       : {torch.__version__}")
print(f"   Transformers  : {transformers.__version__}")
print(f"   GPU tersedia  : {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"   GPU           : {torch.cuda.get_device_name(0)}")
    print(f"   VRAM total    : {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")
# Out:
# Semua library berhasil di-import.
#    PyTorch       : 2.10.0+cu128
#    Transformers  : 5.0.0
#    GPU tersedia  : True
#    GPU           : Tesla T4
#    VRAM total    : 15.6 GB

# %%
# ================================================================
# SEL 1 -- Instalasi Dependensi BERTopic (Post-Training)
# ================================================================
# !pip install -q bertopic sentence-transformers umap-learn hdbscan
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.7/154.7 kB 7.9 MB/s eta 0:00:00

# %% [markdown]
# **Catatan BERTopic:** BERTopic dijalankan setelah training classifier IndoBERT selesai (post-training), sehingga **tidak mempengaruhi akurasi maupun kecepatan training baseline** sama sekali.

# %%
# ================================================================
# SEL 2 -- Konfigurasi Utama (Config)
# ================================================================
# CONSTRAINT (tidak boleh diubah per spesifikasi):
#   train_batch_size = 96   <- optimal untuk VRAM 15 GB (fp16)
#   eval_batch_size  = 384  <- evaluasi cepat, inference-only
#   max_length       = 256  <- sesuai panjang teks dataset berita
#
# [FIX Q1] cudnn.deterministic=True & benchmark=False
#           Reproduktifitas penuh; tanpa ini cuDNN memilih kernel
#           secara non-deterministik antar-run meski seed sama.
# ================================================================
@dataclass
class Config:
    # -- Path Dataset ------------------------------------------------
    path_cnn    : str   = "/content/dataset/Summarized_CNN.csv"
    path_detik  : str   = "/content/dataset/Summarized_Detik.csv"
    path_kompas : str   = "/content/dataset/Summarized_Kompas.csv"
    path_tbh    : str   = "/content/dataset/Summarized_TurnBackHoax.csv"
    path_extra  : str   = "/content/dataset/Summarized_2020+.csv"
    # -- Model -------------------------------------------------------
    model_name       : str   = "indolem/indobert-base-uncased"
    # -- Hyperparameter Training -------------------------------------
    max_length       : int   = 256    # <- CONSTRAINT
    train_batch_size : int   = 96     # <- CONSTRAINT
    eval_batch_size  : int   = 384    # <- CONSTRAINT
    grad_accumulation: int   = 2
    learning_rate    : float = 2e-5
    weight_decay     : float = 0.01
    num_epochs       : int   = 3
    seed             : int   = 42
    # -- Balancing ---------------------------------------------------
    balance_minority : bool  = True
    # -- Output ------------------------------------------------------
    output_dir       : str   = "indobert_hoax_model_v3"

cfg = Config()
set_seed(cfg.seed)

# [FIX Q1] Reproduktifitas penuh pada operasi CUDA
torch.backends.cudnn.deterministic = True   # pilih kernel deterministik
torch.backends.cudnn.benchmark     = False  # nonaktifkan auto-tuner

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Device aktif           : {device}")
print(f"cudnn.deterministic    : {torch.backends.cudnn.deterministic}   [FIX Q1]")
print(f"cudnn.benchmark        : {torch.backends.cudnn.benchmark}  [FIX Q1]")
print(f"train_batch_size       : {cfg.train_batch_size}  CONSTRAINT")
print(f"eval_batch_size        : {cfg.eval_batch_size} CONSTRAINT")
print(f"Efektif batch size     : {cfg.train_batch_size * cfg.grad_accumulation}")
print(f"max_length             : {cfg.max_length}  CONSTRAINT")
# Out:
# Device aktif           : cuda
# cudnn.deterministic    : True   [FIX Q1]
# cudnn.benchmark        : False  [FIX Q1]
# train_batch_size       : 96  CONSTRAINT
# eval_batch_size        : 384 CONSTRAINT
# Efektif batch size     : 192
# max_length             : 256  CONSTRAINT

# %%
# ================================================================
# SEL 3 -- Konfigurasi BERTopic (Post-Training, Opsional)
# ================================================================
# [FIX MR-3] BERTOPIC_HITUNG_PROB=False  -> fit 2-3x lebih cepat
# [FIX Q3]   NR_TOPIK="auto"             -> merge topik mirip otomatis
# [V3]       AKTIFKAN_GUIDED=True        -> seed_topic_list aktif
# ================================================================
AKTIFKAN_BERTOPIC        = True
AKTIFKAN_UNGGAH_BERTOPIC = False
AKTIFKAN_GUIDED          = True   # [V3] Guided Topic Modeling

DIR_OUTPUT_BERTOPIC      = "/content/bertopic_model_v3"
MODEL_EMBEDDING_BERTOPIC = "sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2"
UKURAN_BATCH_EMBED       = 32
UKURAN_BATCH_EKSTRAK     = 128    # [V3] batch size ekstraksi IndoBERT CLS
MAKS_DOKUMEN_BERTOPIC    = None
REPO_TOPIC_HF            = "fjrmhri/deteksi_hoaks_bertopic"
BERTOPIC_HITUNG_PROB     = False  # [FIX MR-3]
NR_TOPIK                 = "auto" # [FIX Q3]

SEED_BERTOPIC = cfg.seed

print(f"BERTopic aktif         : {AKTIFKAN_BERTOPIC}")
print(f"Guided Topic Modeling  : {AKTIFKAN_GUIDED}    [V3]")
print(f"Hitung probabilitas    : {BERTOPIC_HITUNG_PROB}   [FIX MR-3]")
print(f"nr_topics              : {NR_TOPIK}           [FIX Q3]")
print(f"Output dir             : {DIR_OUTPUT_BERTOPIC}  [V3]")
# Out:
# BERTopic aktif         : True
# Guided Topic Modeling  : True    [V3]
# Hitung probabilitas    : False   [FIX MR-3]
# nr_topics              : auto           [FIX Q3]
# Output dir             : /content/bertopic_model_v3  [V3]

# %% [markdown]
# ## [V3] Guided Topic Modeling — `seed_topic_list`
#
# Daftar kata kunci per kategori digunakan sebagai panduan awal BERTopic agar topik lebih terstruktur dan tidak terlalu granular.

# %%
# ================================================================
# SEL 3b -- [V3] Definisi Tema Utama untuk Guided BERTopic
# ================================================================
# seed_topic_list: list of list of str
# Setiap sub-list = satu tema; BERTopic menggunakannya sebagai
# prior saat clustering — bukan hard constraint.
# ================================================================
daftar_tema_utama = [
    # 1. Nasional & Pemerintahan
    ["kementerian", "menteri", "kebijakan", "infrastruktur", "asn",
     "pns", "pemerintah", "presiden", "ibukota", "otonomi",
     "daerah", "regulasi", "proyek", "pembangunan"],

    # 2. Politik
    ["pemilu", "pilkada", "dpr", "partai", "kampanye",
     "bawaslu", "kpu", "pilpres", "caleg", "koalisi",
     "oposisi", "legislasi", "debat", "suara", "konstitusi"],

    # 3. Olahraga
    ["olahraga", "sepakbola", "futsal", "basket", "bulutangkis",
     "atlet", "turnamen", "medali", "piala", "fifa",
     "aff", "liga", "stadion", "pertandingan", "klub"],

    # 4. Ekonomi & Bisnis
    ["ekonomi", "saham", "investasi", "inflasi", "bank",
     "keuangan", "pajak", "ihsg", "umkm", "harga",
     "pasar", "ekspor", "impor", "startup", "bisnis", "perdagangan"],

    # 5. Kriminal & Hukum
    ["polisi", "tersangka", "pengadilan", "hukum", "penjara",
     "korupsi", "kpk", "pembunuhan", "penipuan", "sidang",
     "vonis", "kriminal", "kasus", "penyidikan"],

    # 6. Kesehatan
    ["kesehatan", "penyakit", "rumah sakit", "dokter", "virus",
     "vaksin", "obat", "bpjs", "pandemi", "medis",
     "gejala", "terapi", "pasien", "klinis"],

    # 7. Teknologi & Sains
    ["teknologi", "internet", "aplikasi", "ai", "digital",
     "siber", "hacker", "inovasi", "satelit", "algoritma",
     "perangkat", "data", "machine learning", "sistem"],

    # 8. Hiburan & Gaya Hidup
    ["artis", "film", "musik", "konser", "selebritas",
     "bioskop", "drama", "viral", "sinetron", "festival",
     "gaya", "influencer", "lifestyle"],

    # 9. Bencana & Cuaca
    ["gempa", "banjir", "cuaca", "bmkg", "tsunami",
     "longsor", "erupsi", "badai", "evakuasi", "korban",
     "mitigasi", "iklim", "hujan", "angin"],

    # 10. Pendidikan
    ["sekolah", "guru", "siswa", "mahasiswa", "kampus",
     "universitas", "beasiswa", "kurikulum", "ujian",
     "akademik", "pembelajaran", "riset"],

    # 11. Internasional
    ["luar negeri", "global", "diplomasi", "perang", "konflik",
     "pbb", "nato", "geopolitik", "negara", "internasional", "sanksi"],

    # 12. Transportasi & Infrastruktur
    ["jalan", "tol", "kereta", "bandara", "pelabuhan",
     "transportasi", "kendaraan", "logistik", "infrastruktur", "proyek"],

    # 13. Lingkungan & Energi
    ["lingkungan", "energi", "listrik", "minyak", "gas",
     "emisi", "polusi", "renewable", "energi terbarukan", "tambang"],
]

if AKTIFKAN_GUIDED:
    print(f"[V3] seed_topic_list aktif: {len(daftar_tema_utama)} kategori tema")
    for i, tema in enumerate(daftar_tema_utama, 1):
        print(f"  {i:02d}. {tema[0]} ... ({len(tema)} keyword)")
else:
    print("[V3] AKTIFKAN_GUIDED=False — seed_topic_list tidak akan digunakan")
# Out:
# [V3] seed_topic_list aktif: 13 kategori tema
#   01. kementerian ... (14 keyword)
#   02. pemilu ... (15 keyword)
#   03. olahraga ... (15 keyword)
#   04. ekonomi ... (16 keyword)
#   05. polisi ... (14 keyword)
#   06. kesehatan ... (14 keyword)
#   07. teknologi ... (14 keyword)
#   08. artis ... (13 keyword)
#   09. gempa ... (14 keyword)
#   10. sekolah ... (12 keyword)
#   11. luar negeri ... (11 keyword)
#   12. jalan ... (10 keyword)
#   13. lingkungan ... (10 keyword)

# %%
# ================================================================
# SEL 4 -- Unduh Dataset dari Kaggle
# ================================================================
kaggle_cache_dir = kagglehub.dataset_download("fjrmhri/dataset-berita")
print("Path dataset (cache kagglehub):", kaggle_cache_dir)

direktori_dataset = Path("/content/dataset")
direktori_dataset.mkdir(parents=True, exist_ok=True)

pemetaan_berkas = {
    "Summarized_CNN.csv":          ["dataset/Summarized_CNN.csv"],
    "Summarized_Detik.csv":        ["dataset/Summarized_Detik.csv"],
    "Summarized_Kompas.csv":       ["dataset/Summarized_Kompas.csv"],
    "Summarized_TurnBackHoax.csv": ["dataset/Summarized_TurnBackHoax.csv"],
    "Summarized_2020+.csv":        ["dataset/Summarized_2020+.csv"],
}

for nama_tujuan, kandidat_path in pemetaan_berkas.items():
    ditemukan = None
    for kandidat in kandidat_path:
        path_kandidat = Path(kaggle_cache_dir) / kandidat
        if path_kandidat.exists():
            ditemukan = path_kandidat
            break
    if ditemukan is None:
        raise FileNotFoundError(f"Berkas tidak ditemukan: {nama_tujuan}")
    shutil.copy(ditemukan, direktori_dataset / nama_tujuan)
    print(f"  Disalin: {ditemukan.name} -> {direktori_dataset / nama_tujuan}")

print("\nDataset siap di /content/dataset")
# Out:
# Downloading to /root/.cache/kagglehub/datasets/fjrmhri/dataset-berita/1.archive...
# 100%|██████████| 98.2M/98.2M [00:08<00:00, 12.0MB/s]
# Extracting files...
# Path dataset (cache kagglehub): /root/.cache/kagglehub/datasets/fjrmhri/dataset-berita/versions/1
#   Disalin: Summarized_CNN.csv -> /content/dataset/Summarized_CNN.csv
#   Disalin: Summarized_Detik.csv -> /content/dataset/Summarized_Detik.csv
#   Disalin: Summarized_Kompas.csv -> /content/dataset/Summarized_Kompas.csv
#   Disalin: Summarized_TurnBackHoax.csv -> /content/dataset/Summarized_TurnBackHoax.csv
#   Disalin: Summarized_2020+.csv -> /content/dataset/Summarized_2020+.csv
#
# Dataset siap di /content/dataset

# %%
# ================================================================
# SEL 5 -- Pemuatan Data (Data Loading)
# ================================================================
KOLOM_DASAR = [
    "url", "judul", "tanggal", "isi_berita",
    "Narasi", "Clean Narasi", "hoax", "summary",
]


def muat_satu_dataset(path: str, nama_sumber: str) -> pd.DataFrame:
    if not os.path.exists(path):
        raise FileNotFoundError(f"File tidak ditemukan: {path}")
    print(f"\nMembaca: {path}  (sumber={nama_sumber})")
    df = pd.read_csv(path)
    print("  Kolom tersedia:", list(df.columns))
    for kol in KOLOM_DASAR:
        if kol not in df.columns:
            df[kol] = "" if kol != "hoax" else np.nan
    df = df[KOLOM_DASAR].copy()
    df["source"] = nama_sumber
    return df


def muat_semua_dataset(cfg: Config) -> pd.DataFrame:
    kumpulan: List[pd.DataFrame] = []
    kumpulan.append(muat_satu_dataset(cfg.path_cnn,    "cnn"))
    kumpulan.append(muat_satu_dataset(cfg.path_detik,  "detik"))
    kumpulan.append(muat_satu_dataset(cfg.path_kompas, "kompas"))
    kumpulan.append(muat_satu_dataset(cfg.path_tbh,    "turnbackhoax"))
    kumpulan.append(muat_satu_dataset(cfg.path_extra,  "merged_extra"))
    df_gabung = pd.concat(kumpulan, ignore_index=True)
    print(f"\nTotal baris (mentah): {len(df_gabung):,}")
    return df_gabung

# %%
# ================================================================
# SEL 6 -- Pra-pemrosesan & Pelabelan
# ================================================================
# [FIX HR-2] "summary" masuk rantai fallback pilih_teks setelah
#             "isi_berita" -- lebih padat semantik dari "judul".
# [FIX MR-1] Dedup ketat: teks dengan label konflik dihapus.
# ================================================================

def bangun_dataframe_training(df_mentah: pd.DataFrame) -> pd.DataFrame:
    df = df_mentah.copy()

    def pilih_teks(baris):
        # Prioritas: Clean Narasi -> Narasi -> isi_berita -> summary -> judul
        for kol in ["Clean Narasi", "Narasi", "isi_berita", "summary", "judul"]:
            nilai = baris.get(kol, "")
            if isinstance(nilai, str) and nilai.strip():
                return nilai.strip()
        return ""

    df["text"] = df.apply(pilih_teks, axis=1).astype(str).str.strip()

    n = len(df)
    df = df[df["text"] != ""].reset_index(drop=True)
    print(f"Baris tanpa teks dibuang       : {n - len(df):,}")

    df["hoax_num"] = pd.to_numeric(df["hoax"], errors="coerce")
    mask_nan = df["hoax_num"].isna()
    df.loc[(df["source"].isin(["cnn","detik","kompas"])) & mask_nan, "hoax_num"] = 0
    df.loc[(df["source"] == "turnbackhoax") & mask_nan, "hoax_num"] = 1
    df.loc[(df["source"] == "merged_extra")  & mask_nan, "hoax_num"] = 0

    n = len(df)
    df = df[df["hoax_num"].isin([0, 1])].reset_index(drop=True)
    print(f"Baris label NaN dibuang        : {n - len(df):,}")

    df["label"] = df["hoax_num"].astype(int)
    df = df.drop(columns=["hoax_num"])

    n = len(df)
    df = df.drop_duplicates(subset=["text", "label"])
    print(f"Duplikat (text+label) dibuang  : {n - len(df):,}")

    # [FIX MR-1] Hapus teks dengan label konflik
    unik_per_label = df.groupby("text")["label"].nunique()
    teks_konflik   = unik_per_label[unik_per_label > 1].index
    n = len(df)
    df = df[~df["text"].isin(teks_konflik)].reset_index(drop=True)
    print(f"Teks label-konflik dibuang     : {n - len(df):,} baris "
          f"({len(teks_konflik):,} teks unik)  [FIX MR-1]")

    print(f"\nTotal baris bersih: {len(df):,}")
    print(df["label"].value_counts().to_string())
    print(df.groupby("source")["label"].value_counts().unstack(fill_value=0).to_string())
    return df

# %%
# ================================================================
# SEL 7 -- Pembagian Data & Penyeimbangan Kelas
# ================================================================
def bagi_data_stratified(df: pd.DataFrame, seed: int = 42
) -> Tuple[pd.DataFrame, pd.DataFrame, pd.DataFrame]:
    train_df, temp_df = train_test_split(
        df, test_size=0.30, stratify=df["label"], random_state=seed)
    val_df, test_df = train_test_split(
        temp_df, test_size=0.50, stratify=temp_df["label"], random_state=seed)
    print(f"  Train : {len(train_df):,} | Val : {len(val_df):,} | Test : {len(test_df):,}")
    return (train_df.reset_index(drop=True),
            val_df.reset_index(drop=True),
            test_df.reset_index(drop=True))


def seimbangkan_kelas_minoritas(train_df: pd.DataFrame, seed: int = 42) -> pd.DataFrame:
    jumlah = train_df["label"].value_counts()
    print("Distribusi TRAIN sebelum balancing:"); print(jumlah.to_string())
    if len(jumlah) != 2:
        print("Label tidak biner, balancing dilewati."); return train_df
    n_maks = jumlah.max()
    kumpulan = []
    for lbl, df_lbl in train_df.groupby("label"):
        if len(df_lbl) < n_maks:
            df_lbl = resample(df_lbl, replace=True, n_samples=n_maks, random_state=seed)
        kumpulan.append(df_lbl)
    hasil = pd.concat(kumpulan, ignore_index=True)
    hasil = hasil.sample(frac=1.0, random_state=seed).reset_index(drop=True)
    print("Distribusi TRAIN setelah balancing:"); print(hasil["label"].value_counts().to_string())
    return hasil

# %% [markdown]
# ## Visualisasi Distribusi Dataset [A1]
#
# Grafik distribusi label, sampel per sumber, panjang teks, dan label per sumber. Dipanggil setelah `df_bersih` tersedia di SEL 12.

# %%
# ================================================================
# SEL 8 -- Visualisasi Distribusi Dataset  [A1 -- Nice-to-have]
# ================================================================
def visualisasi_distribusi_dataset(df: pd.DataFrame, judul_prefix: str = ""):
    df = df.copy()
    df["panjang_teks"] = df["text"].astype(str).str.len()
    nama_label = {0: "Non-Hoax", 1: "Hoax"}

    fig, axes = plt.subplots(2, 2, figsize=(14, 9))
    fig.suptitle(
        f"Distribusi Dataset Deteksi Hoaks{' -- ' + judul_prefix if judul_prefix else ''}",
        fontsize=14, fontweight="bold", y=1.01)

    # Plot 1: Distribusi Label Global
    hitung_label = df["label"].value_counts().sort_index()
    warna_label  = ["#16A34A", "#DC2626"]
    batang = axes[0,0].bar(
        [nama_label[i] for i in hitung_label.index],
        hitung_label.values, color=warna_label, edgecolor="white")
    for b, v in zip(batang, hitung_label.values):
        axes[0,0].text(b.get_x()+b.get_width()/2, b.get_height()+20,
                        f"{v:,}", ha="center", va="bottom", fontsize=11, fontweight="bold")
    axes[0,0].set_title("Distribusi Label Global", fontsize=11, fontweight="bold")
    axes[0,0].set_ylabel("Jumlah Sampel")
    axes[0,0].set_ylim(0, hitung_label.max()*1.15)
    axes[0,0].grid(axis="y", alpha=0.3)

    # Plot 2: Jumlah Sampel per Sumber
    hitung_sumber = df["source"].value_counts()
    warna_sumber  = plt.cm.Set2(np.linspace(0, 1, len(hitung_sumber)))
    batang2 = axes[0,1].bar(hitung_sumber.index, hitung_sumber.values,
                              color=warna_sumber, edgecolor="white")
    for b, v in zip(batang2, hitung_sumber.values):
        axes[0,1].text(b.get_x()+b.get_width()/2, b.get_height()+10,
                        f"{v:,}", ha="center", va="bottom", fontsize=9)
    axes[0,1].set_title("Jumlah Sampel per Sumber", fontsize=11, fontweight="bold")
    axes[0,1].set_ylabel("Jumlah Sampel")
    axes[0,1].tick_params(axis="x", rotation=20)
    axes[0,1].grid(axis="y", alpha=0.3)

    # Plot 3: Distribusi Panjang Teks
    for lbl, warna in [(0,"#16A34A"),(1,"#DC2626")]:
        subset = df[df["label"]==lbl]["panjang_teks"]
        axes[1,0].hist(subset, bins=50, alpha=0.65, color=warna,
                        label=nama_label[lbl], edgecolor="none")
    axes[1,0].axvline(df["panjang_teks"].median(), color="#1D4ED8",
                       ls="--", lw=1.5,
                       label=f"Median = {df['panjang_teks'].median():.0f}")
    axes[1,0].set_title("Distribusi Panjang Teks (karakter)", fontsize=11, fontweight="bold")
    axes[1,0].set_xlabel("Panjang Teks"); axes[1,0].set_ylabel("Frekuensi")
    axes[1,0].legend(fontsize=9); axes[1,0].grid(axis="y", alpha=0.3)

    # Plot 4: Label per Sumber (Stacked Bar)
    tabel = df.groupby(["source","label"]).size().unstack(fill_value=0)
    tabel.columns = [nama_label[c] for c in tabel.columns]
    tabel.plot(kind="bar", ax=axes[1,1], color=["#16A34A","#DC2626"],
               edgecolor="white", linewidth=0.8)
    axes[1,1].set_title("Distribusi Label per Sumber", fontsize=11, fontweight="bold")
    axes[1,1].set_xlabel(""); axes[1,1].set_ylabel("Jumlah Sampel")
    axes[1,1].tick_params(axis="x", rotation=20)
    axes[1,1].legend(title="Label"); axes[1,1].grid(axis="y", alpha=0.3)

    plt.tight_layout()
    plt.savefig("distribusi_dataset.png", dpi=150, bbox_inches="tight")
    plt.show()
    print("Grafik disimpan ke: distribusi_dataset.png")
    print(f"\nStatistik Panjang Teks:")
    print(df["panjang_teks"].describe().round(1).to_string())
    print(f"\nRasio Hoax: {df['label'].mean()*100:.1f}%")

# %%
# ================================================================
# SEL 9 -- Login Hugging Face
# ================================================================
from huggingface_hub import login
login()

# %%
# ================================================================
# SEL 10 -- Tokenisasi & Konversi ke HuggingFace Dataset
# ================================================================
# [FIX LR-5] Bug __index_level removal diperbaiki dengan fungsi
#             helper hapus_kolom_index() yang mengembalikan dataset baru.
# ================================================================
tokenizer = AutoTokenizer.from_pretrained(cfg.model_name)


def tokenisasi_batch(batch):
    return tokenizer(batch["text"], truncation=True, max_length=cfg.max_length)


def hapus_kolom_index(ds: Dataset) -> Dataset:
    cols_idx = [c for c in ds.column_names if c.startswith("__index_level")]
    return ds.remove_columns(cols_idx) if cols_idx else ds


def siapkan_dataset_hf(
    train_df: pd.DataFrame, val_df: pd.DataFrame, test_df: pd.DataFrame
) -> Tuple[Dataset, Dataset, Dataset]:
    kol = ["text", "label", "source"]
    ds_train = hapus_kolom_index(Dataset.from_pandas(train_df[kol]))
    ds_val   = hapus_kolom_index(Dataset.from_pandas(val_df[kol]))
    ds_test  = hapus_kolom_index(Dataset.from_pandas(test_df[kol]))

    ds_train = ds_train.map(tokenisasi_batch, batched=True)
    ds_val   = ds_val.map(tokenisasi_batch,   batched=True)
    ds_test  = ds_test.map(tokenisasi_batch,  batched=True)

    kol_m = ["input_ids","attention_mask","label"]
    ds_train.set_format(type="torch", columns=kol_m)
    ds_val.set_format(type="torch",   columns=kol_m)
    ds_test.set_format(type="torch",  columns=kol_m)

    print(f"Train: {len(ds_train):,} | Val: {len(ds_val):,} | Test: {len(ds_test):,}")
    return ds_train, ds_val, ds_test
# Out:
# config.json: 0.00B [00:00, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# added_tokens.json:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
# ================================================================
# SEL 11 -- Definisi Model, Metrik & Konfigurasi Training
# ================================================================
# [FIX LR-1] eval_strategy="epoch", save_strategy="epoch",
#             load_best_model_at_end=True, metric_for_best_model="f1"
# [FIX LR-3] warmup_steps dihitung dari warmup_ratio=0.06, lr_scheduler_type="linear"
# [FIX LR-1] report_to="none" -- nonaktifkan wandb/mlflow
# [FIX Q2]   dataloader_num_workers=0 -- cegah deadlock di Colab
# [FIX O1]   group_by_length=True -- +10-15% kecepatan training
# [FIX O3]   dataloader_pin_memory=True -- transfer CPU->GPU lebih cepat
# [FIX V1]   Trainer dibuat di SEL 12 setelah dataset tersedia (eval_dataset != None)
# ================================================================
label_ke_id = {"not_hoax": 0, "hoax": 1}
id_ke_label = {v: k for k, v in label_ke_id.items()}

model = AutoModelForSequenceClassification.from_pretrained(
    cfg.model_name,
    num_labels=2,
    id2label=id_ke_label,
    label2id={v: k for k, v in id_ke_label.items()},
).to(device)

collator_padding = DataCollatorWithPadding(tokenizer=tokenizer)


def hitung_metrik(eval_pred):
    logits, labels = eval_pred
    prediksi = np.argmax(logits, axis=-1)
    akurasi  = accuracy_score(labels, prediksi)
    prec_b, rec_b, f1_b, _ = precision_recall_fscore_support(
        labels, prediksi, average="binary", pos_label=1)
    prec_w, rec_w, f1_w, _ = precision_recall_fscore_support(
        labels, prediksi, average="weighted")
    return {
        "accuracy":           float(akurasi),
        "precision":          float(prec_b),
        "recall":             float(rec_b),
        "f1":                 float(f1_b),
        "precision_weighted": float(prec_w),
        "recall_weighted":    float(rec_w),
        "f1_weighted":        float(f1_w),
    }


# Hitung total steps untuk warmup (pengganti warmup_ratio yang deprecated)
_steps_per_epoch = max(1, len(getattr(cfg, "train_size", 1)) // (cfg.train_batch_size * cfg.grad_accumulation)) if hasattr(cfg, "train_size") else None
# warmup_steps akan dihitung ulang di SEL 12 setelah dataset tersedia

argumen_training = TrainingArguments(
    output_dir                  = cfg.output_dir,
    per_device_train_batch_size = cfg.train_batch_size,   # 96 CONSTRAINT
    per_device_eval_batch_size  = cfg.eval_batch_size,    # 384 CONSTRAINT
    gradient_accumulation_steps = cfg.grad_accumulation,
    num_train_epochs            = cfg.num_epochs,
    learning_rate               = cfg.learning_rate,
    weight_decay                = cfg.weight_decay,
    warmup_ratio                = 0.06,        # [FIX LR-3] masih valid, hanya warning
    lr_scheduler_type           = "linear",    # [FIX LR-3]
    eval_strategy               = "epoch",     # [FIX V1] ganti dari evaluation_strategy
    save_strategy               = "epoch",     # [FIX LR-1]
    load_best_model_at_end      = True,        # [FIX LR-1]
    metric_for_best_model       = "f1",        # [FIX LR-1]
    greater_is_better           = True,
    logging_steps               = 50,
    save_total_limit            = 2,
    fp16                        = torch.cuda.is_available(),
    dataloader_num_workers      = 0,           # [FIX Q2] aman di Colab
    dataloader_pin_memory       = True,        # [FIX O3]
    group_by_length             = True,        # [FIX O1] +10-15% speed
    do_train                    = True,
    do_eval                     = True,
    seed                        = cfg.seed,
    report_to                   = "none",      # [FIX LR-1]
)

# [FIX V1] Trainer TIDAK dibuat di sini karena eval_dataset belum tersedia.
# Trainer akan dibuat di SEL 12 setelah ds_train dan ds_val siap.
print("Model & argumen_training siap.")
print(f"   eval_strategy         : {argumen_training.eval_strategy}  [FIX V1]")
print(f"   Best model criterion  : {argumen_training.metric_for_best_model}")
print(f"   group_by_length       : {argumen_training.group_by_length}  [FIX O1]")
print(f"   dataloader_num_workers: {argumen_training.dataloader_num_workers}   [FIX Q2]")
print(f"   dataloader_pin_memory : {argumen_training.dataloader_pin_memory}  [FIX O3]")
# Out:
# pytorch_model.bin:   0%|          | 0.00/445M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertForSequenceClassification LOAD REPORT from: indolem/indobert-base-uncased
# Key                                        | Status     |
# -------------------------------------------+------------+-
# cls.predictions.decoder.weight             | UNEXPECTED |
# cls.predictions.bias                       | UNEXPECTED |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |
# cls.predictions.decoder.bias               | UNEXPECTED |
# cls.predictions.transform.dense.bias       | UNEXPECTED |
# cls.predictions.transform.dense.weight     | UNEXPECTED |
# classifier.weight                          | MISSING    |
# classifier.bias                            | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# warmup_ratio is deprecated and will be removed in v5.2. Use `warmup_steps` instead.
# Model & argumen_training siap.
#    eval_strategy         : IntervalStrategy.EPOCH  [FIX V1]
#    Best model criterion  : f1
#    group_by_length       : True  [FIX O1]
#    dataloader_num_workers: 0   [FIX Q2]
#    dataloader_pin_memory : True  [FIX O3]

# %%
# ================================================================
# SEL 12 -- Pipeline End-to-End: Muat -> Proses -> Latih -> Evaluasi
# ================================================================
# [FIX MR-2] train_df_pra_oversampling disimpan sebelum balancing
# [FIX B2]   _cache_prediksi.clear() dipanggil setelah training
# ================================================================

df_mentah = muat_semua_dataset(cfg)
df_bersih = bangun_dataframe_training(df_mentah)

# [A1] Visualisasi distribusi dataset
visualisasi_distribusi_dataset(df_bersih, judul_prefix="Setelah Pembersihan")

train_df, val_df, test_df = bagi_data_stratified(df_bersih, seed=cfg.seed)

# [FIX MR-2] Simpan corpus pra-oversampling untuk BERTopic
train_df_pra_oversampling = train_df.copy()
print(f"\n[FIX MR-2] Corpus BERTopic (pra-oversampling): {len(train_df_pra_oversampling):,}")

if cfg.balance_minority:
    train_df = seimbangkan_kelas_minoritas(train_df, seed=cfg.seed)

ds_train, ds_val, ds_test = siapkan_dataset_hf(train_df, val_df, test_df)

# [FIX V1] Buat Trainer di sini setelah dataset tersedia (bukan di SEL 11)
trainer = Trainer(
    model           = model,
    args            = argumen_training,
    train_dataset   = ds_train,
    eval_dataset    = ds_val,
    data_collator   = collator_padding,
    compute_metrics = hitung_metrik,
)
print(f"Trainer siap  — train: {len(ds_train):,}  |  val: {len(ds_val):,}")

print("\n" + "="*60)
print("Memulai training IndoBERT...")
print("="*60)
hasil_training = trainer.train()

print(f"\nTraining selesai.")
print(f"   Checkpoint terbaik : {trainer.state.best_model_checkpoint}")
print(f"   Metrik terbaik (f1): {trainer.state.best_metric:.4f}")

log_history_training = list(trainer.state.log_history)

# [FIX B2] Reset cache prediksi agar tidak stale jika sel ini dijalankan ulang
_cache_prediksi: Dict[str, object] = {}
print("\n[FIX B2] Cache prediksi direset setelah training baru selesai.")

print("\n" + "="*60 + "\nEvaluasi VALIDATION SET\n" + "="*60)
metrik_val = trainer.evaluate(ds_val); print(metrik_val)

print("\n" + "="*60 + "\nEvaluasi TEST SET\n" + "="*60)
metrik_test = trainer.evaluate(ds_test); print(metrik_test)
# Out:
# Membaca: /content/dataset/Summarized_CNN.csv  (sumber=cnn)
#   Kolom tersedia: ['url', 'judul', 'tanggal', 'isi_berita', 'Narasi', 'Clean Narasi', 'hoax', 'summary']
#
# Membaca: /content/dataset/Summarized_Detik.csv  (sumber=detik)
# Exception in thread Thread-auto_conversion:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.12/threading.py", line 1012, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/transformers/safetensors_conversion.py", line 116, in auto_conversion
#     raise e
#   File "/usr/local/lib/python3.12/dist-packages/transformers/safetensors_conversion.py", line 95, in auto_conversion
#     sha = get_conversion_pr_reference(api, pretrained_model_name_or_path, **cached_file_kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/safetensors_conversion.py", line 71, in get_conversion_pr_reference
#     spawn_conversion(token, private, model_id)
#   File "/usr/local/lib/python3.12/dist-packages/transformers/safetensors_conversion.py", line 47, in spawn_conversion
#     result = httpx.post(sse_url, follow_redirects=True, json=data).json()
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/httpx/_models.py", line 832, in json
#     return jsonlib.loads(self.content, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/json/__init__.py", line 346, in loads
#     return _default_decoder.decode(s)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/json/decoder.py", line 338, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/json/decoder.py", line 356, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#   Kolom tersedia: ['url', 'judul', 'tanggal', 'isi_berita', 'Narasi', 'Clean Narasi', 'hoax', 'summary']
#
# Membaca: /content/dataset/Summarized_Kompas.csv  (sumber=kompas)
#   Kolom tersedia: ['url', 'judul', 'tanggal', 'isi_berita', 'Narasi', 'Clean Narasi', 'hoax', 'summary']
#
# Membaca: /content/dataset/Summarized_TurnBackHoax.csv  (sumber=turnbackhoax)
#   Kolom tersedia: ['url', 'judul', 'tanggal', 'isi_berita', 'Narasi', 'Clean Narasi', 'hoax', 'summary']
#
# Membaca: /content/dataset/Summarized_2020+.csv  (sumber=merged_extra)
#   Kolom tersedia: ['url', 'judul', 'tanggal', 'isi_berita', 'Narasi', 'Clean Narasi', 'summary', 'source_file', 'hoax']
#
# Total baris (mentah): 173,229
# Baris tanpa teks dibuang       : 0
# Baris label NaN dibuang        : 0
# Duplikat (text+label) dibuang  : 1,055
# Teks label-konflik dibuang     : 0 baris (0 teks unik)  [FIX MR-1]
#
# Total baris bersih: 172,174
# label
# 0    160221
# 1     11953
# label              0      1
# source
# cnn             4216      0
# detik           4213      0
# kompas          4216      0
# merged_extra  147576      0
# turnbackhoax       0  11953
# Grafik disimpan ke: distribusi_dataset.png
#
# Statistik Panjang Teks:
# count    172174.0
# mean        704.0
# std         978.8
# min           1.0
# 25%          52.0
# 50%          68.0
# 75%        1306.0
# max       29140.0
#
# Rasio Hoax: 6.9%
#   Train : 120,521 | Val : 25,826 | Test : 25,827
#
# [FIX MR-2] Corpus BERTopic (pra-oversampling): 120,521
# Distribusi TRAIN sebelum balancing:
# label
# 0    112154
# 1      8367
# Distribusi TRAIN setelah balancing:
# label
# 0    112154
# 1    112154
# Map:   0%|          | 0/224308 [00:00<?, ? examples/s]
# Map:   0%|          | 0/25826 [00:00<?, ? examples/s]
# Map:   0%|          | 0/25827 [00:00<?, ? examples/s]
# Train: 224,308 | Val: 25,826 | Test: 25,827
# Trainer siap  — train: 224,308  |  val: 25,826
#
# ============================================================
# Memulai training IndoBERT...
# ============================================================
#     <div>
#
#       <progress value='3507' max='3507' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3507/3507 44:58, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Precision Weighted</th>
#       <th>Recall Weighted</th>
#       <th>F1 Weighted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.017970</td>
#       <td>0.014565</td>
#       <td>0.996438</td>
#       <td>0.960976</td>
#       <td>0.988846</td>
#       <td>0.974711</td>
#       <td>0.996515</td>
#       <td>0.996438</td>
#       <td>0.996461</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.004082</td>
#       <td>0.010525</td>
#       <td>0.997715</td>
#       <td>0.985987</td>
#       <td>0.981037</td>
#       <td>0.983506</td>
#       <td>0.997711</td>
#       <td>0.997715</td>
#       <td>0.997713</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.000824</td>
#       <td>0.009711</td>
#       <td>0.998374</td>
#       <td>0.989927</td>
#       <td>0.986615</td>
#       <td>0.988268</td>
#       <td>0.998372</td>
#       <td>0.998374</td>
#       <td>0.998372</td>
#     </tr>
#   </tbody>
# </table><p>
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# There were missing keys in the checkpoint model loaded: ['bert.embeddings.LayerNorm.weight', 'bert.embeddings.LayerNorm.bias', 'bert.encoder.layer.0.attention.output.LayerNorm.weight', 'bert.encoder.layer.0.attention.output.LayerNorm.bias', 'bert.encoder.layer.0.output.LayerNorm.weight', 'bert.encoder.layer.0.output.LayerNorm.bias', 'bert.encoder.layer.1.attention.output.LayerNorm.weight', 'bert.encoder.layer.1.attention.output.LayerNorm.bias', 'bert.encoder.layer.1.output.LayerNorm.weight', 'bert.encoder.layer.1.output.LayerNorm.bias', 'bert.encoder.layer.2.attention.output.LayerNorm.weight', 'bert.encoder.layer.2.attention.output.LayerNorm.bias', 'bert.encoder.layer.2.output.LayerNorm.weight', 'bert.encoder.layer.2.output.LayerNorm.bias', 'bert.encoder.layer.3.attention.output.LayerNorm.weight', 'bert.encoder.layer.3.attention.output.LayerNorm.bias', 'bert.encoder.layer.3.output.LayerNorm.weight', 'bert.encoder.layer.3.output.LayerNorm.bias', 'bert.encoder.layer.4.attention.output.LayerNorm.weight', 'bert.encoder.layer.4.attention.output.LayerNorm.bias', 'bert.encoder.layer.4.output.LayerNorm.weight', 'bert.encoder.layer.4.output.LayerNorm.bias', 'bert.encoder.layer.5.attention.output.LayerNorm.weight', 'bert.encoder.layer.5.attention.output.LayerNorm.bias', 'bert.encoder.layer.5.output.LayerNorm.weight', 'bert.encoder.layer.5.output.LayerNorm.bias', 'bert.encoder.layer.6.attention.output.LayerNorm.weight', 'bert.encoder.layer.6.attention.output.LayerNorm.bias', 'bert.encoder.layer.6.output.LayerNorm.weight', 'bert.encoder.layer.6.output.LayerNorm.bias', 'bert.encoder.layer.7.attention.output.LayerNorm.weight', 'bert.encoder.layer.7.attention.output.LayerNorm.bias', 'bert.encoder.layer.7.output.LayerNorm.weight', 'bert.encoder.layer.7.output.LayerNorm.bias', 'bert.encoder.layer.8.attention.output.LayerNorm.weight', 'bert.encoder.layer.8.attention.output.LayerNorm.bias', 'bert.encoder.layer.8.output.LayerNorm.weight', 'bert.encoder.layer.8.output.LayerNorm.bias', 'bert.encoder.layer.9.attention.output.LayerNorm.weight', 'bert.encoder.layer.9.attention.output.LayerNorm.bias', 'bert.encoder.layer.9.output.LayerNorm.weight', 'bert.encoder.layer.9.output.LayerNorm.bias', 'bert.encoder.layer.10.attention.output.LayerNorm.weight', 'bert.encoder.layer.10.attention.output.LayerNorm.bias', 'bert.encoder.layer.10.output.LayerNorm.weight', 'bert.encoder.layer.10.output.LayerNorm.bias', 'bert.encoder.layer.11.attention.output.LayerNorm.weight', 'bert.encoder.layer.11.attention.output.LayerNorm.bias', 'bert.encoder.layer.11.output.LayerNorm.weight', 'bert.encoder.layer.11.output.LayerNorm.bias'].
# There were unexpected keys in the checkpoint model loaded: ['bert.embeddings.LayerNorm.beta', 'bert.embeddings.LayerNorm.gamma', 'bert.encoder.layer.0.attention.output.LayerNorm.beta', 'bert.encoder.layer.0.attention.output.LayerNorm.gamma', 'bert.encoder.layer.0.output.LayerNorm.beta', 'bert.encoder.layer.0.output.LayerNorm.gamma', 'bert.encoder.layer.1.attention.output.LayerNorm.beta', 'bert.encoder.layer.1.attention.output.LayerNorm.gamma', 'bert.encoder.layer.1.output.LayerNorm.beta', 'bert.encoder.layer.1.output.LayerNorm.gamma', 'bert.encoder.layer.2.attention.output.LayerNorm.beta', 'bert.encoder.layer.2.attention.output.LayerNorm.gamma', 'bert.encoder.layer.2.output.LayerNorm.beta', 'bert.encoder.layer.2.output.LayerNorm.gamma', 'bert.encoder.layer.3.attention.output.LayerNorm.beta', 'bert.encoder.layer.3.attention.output.LayerNorm.gamma', 'bert.encoder.layer.3.output.LayerNorm.beta', 'bert.encoder.layer.3.output.LayerNorm.gamma', 'bert.encoder.layer.4.attention.output.LayerNorm.beta', 'bert.encoder.layer.4.attention.output.LayerNorm.gamma', 'bert.encoder.layer.4.output.LayerNorm.beta', 'bert.encoder.layer.4.output.LayerNorm.gamma', 'bert.encoder.layer.5.attention.output.LayerNorm.beta', 'bert.encoder.layer.5.attention.output.LayerNorm.gamma', 'bert.encoder.layer.5.output.LayerNorm.beta', 'bert.encoder.layer.5.output.LayerNorm.gamma', 'bert.encoder.layer.6.attention.output.LayerNorm.beta', 'bert.encoder.layer.6.attention.output.LayerNorm.gamma', 'bert.encoder.layer.6.output.LayerNorm.beta', 'bert.encoder.layer.6.output.LayerNorm.gamma', 'bert.encoder.layer.7.attention.output.LayerNorm.beta', 'bert.encoder.layer.7.attention.output.LayerNorm.gamma', 'bert.encoder.layer.7.output.LayerNorm.beta', 'bert.encoder.layer.7.output.LayerNorm.gamma', 'bert.encoder.layer.8.attention.output.LayerNorm.beta', 'bert.encoder.layer.8.attention.output.LayerNorm.gamma', 'bert.encoder.layer.8.output.LayerNorm.beta', 'bert.encoder.layer.8.output.LayerNorm.gamma', 'bert.encoder.layer.9.attention.output.LayerNorm.beta', 'bert.encoder.layer.9.attention.output.LayerNorm.gamma', 'bert.encoder.layer.9.output.LayerNorm.beta', 'bert.encoder.layer.9.output.LayerNorm.gamma', 'bert.encoder.layer.10.attention.output.LayerNorm.beta', 'bert.encoder.layer.10.attention.output.LayerNorm.gamma', 'bert.encoder.layer.10.output.LayerNorm.beta', 'bert.encoder.layer.10.output.LayerNorm.gamma', 'bert.encoder.layer.11.attention.output.LayerNorm.beta', 'bert.encoder.layer.11.attention.output.LayerNorm.gamma', 'bert.encoder.layer.11.output.LayerNorm.beta', 'bert.encoder.layer.11.output.LayerNorm.gamma'].
# Training selesai.
#    Checkpoint terbaik : indobert_hoax_model_v3/checkpoint-3507
#    Metrik terbaik (f1): 0.9883
#
# [FIX B2] Cache prediksi direset setelah training baru selesai.
#
# ============================================================
# Evaluasi VALIDATION SET
# ============================================================
#     <div>
#
#       <progress value='136' max='68' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [68/68 01:25]
#     </div>
# {'eval_loss': 0.009710859507322311, 'eval_accuracy': 0.9983737318980872, 'eval_precision': 0.9899272523782876, 'eval_recall': 0.9866146123814835, 'eval_f1': 0.988268156424581, 'eval_precision_weighted': 0.9983716237040225, 'eval_recall_weighted': 0.9983737318980872, 'eval_f1_weighted': 0.9983724705931104, 'eval_runtime': 40.4508, 'eval_samples_per_second': 638.455, 'eval_steps_per_second': 1.681, 'epoch': 3.0}
#
# ============================================================
# Evaluasi TEST SET
# ============================================================
# {'eval_loss': 0.01255961786955595, 'eval_accuracy': 0.9982576373562551, 'eval_precision': 0.9932279909706546, 'eval_recall': 0.9815950920245399, 'eval_f1': 0.9873772791023843, 'eval_precision_weighted': 0.9982532464780968, 'eval_recall_weighted': 0.9982576373562551, 'eval_f1_weighted': 0.9982528860093082, 'eval_runtime': 38.0004, 'eval_samples_per_second': 679.651, 'eval_steps_per_second': 1.789, 'epoch': 3.0}

# %%
# ================================================================
# SEL 13 -- Visualisasi Loss Curve & Metrik per Epoch
# ================================================================
def plot_kurva_loss(log_history: list):
    l_step, l_loss = [], []
    e_step, e_loss, e_epoch, e_f1, e_acc = [], [], [], [], []
    for entri in log_history:
        if "loss" in entri and "eval_loss" not in entri:
            l_step.append(entri["step"]); l_loss.append(entri["loss"])
        if "eval_loss" in entri:
            e_step.append(entri["step"]); e_loss.append(entri["eval_loss"])
            if "epoch"        in entri: e_epoch.append(entri["epoch"])
            if "eval_f1"      in entri: e_f1.append(entri["eval_f1"])
            if "eval_accuracy"in entri: e_acc.append(entri["eval_accuracy"])

    if not l_step and not e_step:
        print("Log history kosong."); return

    n_plot = 1 + int(bool(e_step)) + int(bool(e_f1))
    fig, axes = plt.subplots(1, n_plot, figsize=(6*n_plot, 4))
    if n_plot == 1: axes = [axes]

    if l_step:
        axes[0].plot(l_step, l_loss, color="#2563EB", lw=1.5, label="Train Loss")
        axes[0].set_title("Training Loss per Step", fontweight="bold"); axes[0].set_xlabel("Step")
        axes[0].set_ylabel("Loss"); axes[0].legend(); axes[0].grid(True, alpha=0.3)

    if e_step:
        x, xl = (e_epoch,"Epoch") if e_epoch else (e_step,"Step")
        axes[1].plot(x, e_loss, "o-", color="#DC2626", lw=2, ms=6, label="Eval Loss")
        axes[1].set_title("Eval Loss per Epoch", fontweight="bold"); axes[1].set_xlabel(xl)
        axes[1].set_ylabel("Loss"); axes[1].legend(); axes[1].grid(True, alpha=0.3)

    if e_f1:
        x, xl = (e_epoch,"Epoch") if e_epoch else (list(range(1,len(e_f1)+1)),"Checkpoint")
        axes[2].plot(x, e_f1, "s-", color="#16A34A", lw=2, ms=6, label="F1 (hoax)")
        if e_acc:
            axes[2].plot(x, e_acc, "^--", color="#D97706", lw=1.5, ms=5, label="Accuracy")
        axes[2].set_title("Metrik per Epoch", fontweight="bold"); axes[2].set_xlabel(xl)
        axes[2].set_ylabel("Score"); axes[2].set_ylim(0, 1.05)
        axes[2].legend(); axes[2].grid(True, alpha=0.3)

    plt.suptitle("Ringkasan Training IndoBERT -- Hoax Detection", fontsize=13, fontweight="bold", y=1.02)
    plt.tight_layout()
    plt.savefig("kurva_training.png", dpi=150, bbox_inches="tight"); plt.show()
    print("Grafik disimpan ke: kurva_training.png")


plot_kurva_loss(log_history_training)
# Out:
# Grafik disimpan ke: kurva_training.png

# %%
# ================================================================
# SEL 14 -- Laporan Detail & Confusion Matrix
# ================================================================

def dapatkan_prediksi(trainer: Trainer, dataset: Dataset, nama_split: str):
    if nama_split not in _cache_prediksi:
        _cache_prediksi[nama_split] = trainer.predict(dataset)
    return _cache_prediksi[nama_split]


def laporan_detail(trainer: Trainer, dataset: Dataset, nama_split: str):
    out    = dapatkan_prediksi(trainer, dataset, nama_split)
    y_asli = out.label_ids
    y_pred = np.argmax(out.predictions, axis=-1)
    kelas  = ["not_hoax", "hoax"]

    print(f"\n{'='*60}\n  Laporan Klasifikasi -- {nama_split}\n{'='*60}")
    print(classification_report(y_asli, y_pred, target_names=kelas, digits=4))

    cm      = confusion_matrix(y_asli, y_pred)
    cm_norm = cm.astype(float) / cm.sum(axis=1, keepdims=True)
    fig, axes = plt.subplots(1, 2, figsize=(11, 4))

    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
                xticklabels=kelas, yticklabels=kelas, ax=axes[0],
                linewidths=0.5, annot_kws={"size":13,"weight":"bold"})
    axes[0].set_title(f"Confusion Matrix (Jumlah)\n{nama_split}", fontsize=11, fontweight="bold")
    axes[0].set_xlabel("Prediksi"); axes[0].set_ylabel("Aktual")

    sns.heatmap(cm_norm, annot=True, fmt=".3f", cmap="Greens",
                xticklabels=kelas, yticklabels=kelas, ax=axes[1],
                linewidths=0.5, vmin=0, vmax=1, annot_kws={"size":13})
    axes[1].set_title(f"Confusion Matrix (Proporsi Recall)\n{nama_split}", fontsize=11, fontweight="bold")
    axes[1].set_xlabel("Prediksi"); axes[1].set_ylabel("Aktual")

    plt.tight_layout()
    fname = f"confusion_matrix_{nama_split.lower().replace(' ','_')}.png"
    plt.savefig(fname, dpi=150, bbox_inches="tight"); plt.show()
    print(f"Confusion matrix disimpan ke: {fname}")
    return y_asli, y_pred, out.predictions


laporan_detail(trainer, ds_val,  "Validation")
laporan_detail(trainer, ds_test, "Test")
# Out:
# ============================================================
#   Laporan Klasifikasi -- Validation
# ============================================================
#               precision    recall  f1-score   support
#
#     not_hoax     0.9990    0.9993    0.9991     24033
#         hoax     0.9899    0.9866    0.9883      1793
#
#     accuracy                         0.9984     25826
#    macro avg     0.9945    0.9929    0.9937     25826
# weighted avg     0.9984    0.9984    0.9984     25826
# Confusion matrix disimpan ke: confusion_matrix_validation.png
# ============================================================
#   Laporan Klasifikasi -- Test
# ============================================================
#               precision    recall  f1-score   support
#
#     not_hoax     0.9986    0.9995    0.9991     24034
#         hoax     0.9932    0.9816    0.9874      1793
#
#     accuracy                         0.9983     25827
#    macro avg     0.9959    0.9905    0.9932     25827
# weighted avg     0.9983    0.9983    0.9983     25827
# Confusion matrix disimpan ke: confusion_matrix_test.png
# (array([0, 0, 0, ..., 0, 0, 0]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([[ 5.7890625, -6.0390625],
#         [ 5.8320312, -6.0546875],
#         [ 5.8125   , -6.0742188],
#         ...,
#         [ 4.5      , -5.0546875],
#         [ 5.3125   , -5.4726562],
#         [ 2.7597656, -3.2695312]], dtype=float32))

# %%
# ================================================================
# SEL 15 -- Kurva ROC & AUC
# ================================================================
def plot_kurva_roc(trainer, dataset, nama_split, warna="#2563EB"):
    out   = dapatkan_prediksi(trainer, dataset, nama_split)
    probs = torch.softmax(torch.tensor(out.predictions, dtype=torch.float32), dim=-1).numpy()
    fpr, tpr, _ = roc_curve(out.label_ids, probs[:,1], pos_label=1)
    nilai_auc = auc(fpr, tpr)

    plt.figure(figsize=(5, 4))
    plt.plot(fpr, tpr, color=warna, lw=2, label=f"AUC = {nilai_auc:.4f}")
    plt.plot([0,1],[0,1],"k--", lw=1, label="Random Baseline")
    plt.xlabel("False Positive Rate"); plt.ylabel("True Positive Rate")
    plt.title(f"Kurva ROC -- {nama_split}", fontsize=12, fontweight="bold")
    plt.legend(loc="lower right"); plt.grid(True, alpha=0.3); plt.tight_layout()
    fname = f"roc_curve_{nama_split.lower().replace(' ','_')}.png"
    plt.savefig(fname, dpi=150, bbox_inches="tight"); plt.show()
    print(f"ROC curve disimpan ke: {fname}  |  AUC = {nilai_auc:.4f}")
    return nilai_auc


auc_val  = plot_kurva_roc(trainer, ds_val,  "Validation", warna="#2563EB")
auc_test = plot_kurva_roc(trainer, ds_test, "Test",       warna="#DC2626")
# Out:
# ROC curve disimpan ke: roc_curve_validation.png  |  AUC = 0.9994
# ROC curve disimpan ke: roc_curve_test.png  |  AUC = 0.9992

# %%
# ================================================================
# SEL 16 -- Kalibrasi Threshold Optimal  [FIX HR-1]
# ================================================================
def kalibrasi_threshold(trainer, dataset, nama_split="val") -> float:
    out    = dapatkan_prediksi(trainer, dataset, nama_split)
    y_asli = out.label_ids
    probs  = torch.softmax(torch.tensor(out.predictions, dtype=torch.float32), dim=-1).numpy()
    p_hoax = probs[:,1]

    sweep    = np.arange(0.30, 0.80, 0.01)
    riwayat  = [(float(t), float(f1_score(y_asli,(p_hoax>=t).astype(int),
                                           pos_label=1, zero_division=0)))
                for t in sweep]
    t_best, f1_best = max(riwayat, key=lambda x: x[1])

    tv, fv = zip(*riwayat)
    plt.figure(figsize=(7, 4))
    plt.plot(tv, fv, color="#2563EB", lw=2)
    plt.axvline(t_best, color="#DC2626", ls="--", lw=1.5,
                label=f"Optimal = {t_best:.2f}  (F1={f1_best:.4f})")
    plt.axvline(0.5, color="#6B7280", ls=":", lw=1.2, label="Default = 0.50")
    plt.xlabel("Threshold p(hoax)"); plt.ylabel("F1-score (hoax)")
    plt.title(f"Kalibrasi Threshold -- {nama_split}", fontsize=12, fontweight="bold")
    plt.legend(); plt.grid(True, alpha=0.3); plt.tight_layout()
    plt.savefig(f"kalibrasi_threshold_{nama_split}.png", dpi=150, bbox_inches="tight")
    plt.show()

    f1_def = f1_score(y_asli, (p_hoax>=0.5).astype(int), pos_label=1)
    print(f"[{nama_split}] Threshold optimal : {t_best:.2f}")
    print(f"[{nama_split}] F1 hoax @optimal  : {f1_best:.4f}")
    print(f"[{nama_split}] F1 hoax @0.50     : {f1_def:.4f}")
    return t_best


THRESHOLD_OPTIMAL = kalibrasi_threshold(trainer, ds_val, "validation")

out_test = dapatkan_prediksi(trainer, ds_test, "Test")
p_test   = torch.softmax(torch.tensor(out_test.predictions, dtype=torch.float32), dim=-1).numpy()[:,1]
y_test   = out_test.label_ids

f1_def = f1_score(y_test, (p_test>=0.5).astype(int), pos_label=1)
f1_opt = f1_score(y_test, (p_test>=THRESHOLD_OPTIMAL).astype(int), pos_label=1)
print(f"\nTest F1 @0.50     : {f1_def:.4f}")
print(f"Test F1 @{THRESHOLD_OPTIMAL:.2f} (opt): {f1_opt:.4f}")
print(f"\nTHRESHOLD_OPTIMAL = {THRESHOLD_OPTIMAL:.2f}")
# Out:
# [validation] Threshold optimal : 0.62
# [validation] F1 hoax @optimal  : 0.9885
# [validation] F1 hoax @0.50     : 0.9883
#
# Test F1 @0.50     : 0.9874
# Test F1 @0.62 (opt): 0.9874
#
# THRESHOLD_OPTIMAL = 0.62

# %% [markdown]
# ## Tabel Perbandingan Multi-Threshold [A2]
#
# Tabel Precision/Recall/F1 pada berbagai threshold untuk memilih trade-off false positive vs. false negative.

# %%
# ================================================================
# SEL 17 -- Tabel Perbandingan Multi-Threshold  [A2 -- Nice-to-have]
# ================================================================
def tabel_perbandingan_threshold(trainer, dataset, nama_split, threshold_optimal,
                                  threshold_list=None):
    if threshold_list is None:
        threshold_list = [0.30, 0.35, 0.40, 0.45, 0.50,
                          0.55, 0.60, 0.65, 0.70, threshold_optimal]
    threshold_list = sorted(set(round(t, 2) for t in threshold_list))

    out   = dapatkan_prediksi(trainer, dataset, nama_split)
    y     = out.label_ids
    probs = torch.softmax(torch.tensor(out.predictions, dtype=torch.float32), dim=-1).numpy()
    p_h   = probs[:,1]

    baris = []
    for t in threshold_list:
        pred = (p_h >= t).astype(int)
        prec = precision_score(y, pred, pos_label=1, zero_division=0)
        rec  = recall_score(y, pred,    pos_label=1, zero_division=0)
        f1   = f1_score(y, pred,        pos_label=1, zero_division=0)
        tp   = int(((pred==1)&(y==1)).sum())
        fp   = int(((pred==1)&(y==0)).sum())
        fn   = int(((pred==0)&(y==1)).sum())
        ket  = ""
        if abs(t - 0.50) < 0.005:            ket = "<- default"
        if abs(t - threshold_optimal) < 0.005: ket = "<- OPTIMAL"
        baris.append({"Threshold": f"{t:.2f}", "Precision": f"{prec:.4f}",
                       "Recall": f"{rec:.4f}", "F1-Hoax": f"{f1:.4f}",
                       "TP": tp, "FP": fp, "FN": fn, "Keterangan": ket})

    df_t = pd.DataFrame(baris)
    print(f"\n{'='*70}\n  Tabel Perbandingan Threshold -- {nama_split}\n{'='*70}")
    print(df_t.to_string(index=False))
    print("="*70)
    return df_t


tabel_val  = tabel_perbandingan_threshold(trainer, ds_val,  "Validation", THRESHOLD_OPTIMAL)
tabel_test = tabel_perbandingan_threshold(trainer, ds_test, "Test",       THRESHOLD_OPTIMAL)
# Out:
# ======================================================================
#   Tabel Perbandingan Threshold -- Validation
# ======================================================================
# Threshold Precision Recall F1-Hoax   TP  FP  FN Keterangan
#      0.30    0.9883 0.9872  0.9877 1770  21  23
#      0.35    0.9883 0.9872  0.9877 1770  21  23
#      0.40    0.9883 0.9866  0.9874 1769  21  24
#      0.45    0.9899 0.9866  0.9883 1769  18  24
#      0.50    0.9899 0.9866  0.9883 1769  18  24 <- default
#      0.55    0.9899 0.9866  0.9883 1769  18  24
#      0.60    0.9899 0.9866  0.9883 1769  18  24
#      0.62    0.9905 0.9866  0.9885 1769  17  24 <- OPTIMAL
#      0.65    0.9905 0.9866  0.9885 1769  17  24
#      0.70    0.9905 0.9855  0.9880 1767  17  26
# ======================================================================
#
# ======================================================================
#   Tabel Perbandingan Threshold -- Test
# ======================================================================
# Threshold Precision Recall F1-Hoax   TP  FP  FN Keterangan
#      0.30    0.9910 0.9822  0.9866 1761  16  32
#      0.35    0.9921 0.9822  0.9871 1761  14  32
#      0.40    0.9927 0.9822  0.9874 1761  13  32
#      0.45    0.9927 0.9816  0.9871 1760  13  33
#      0.50    0.9932 0.9816  0.9874 1760  12  33 <- default
#      0.55    0.9938 0.9816  0.9877 1760  11  33
#      0.60    0.9938 0.9810  0.9874 1759  11  34
#      0.62    0.9938 0.9810  0.9874 1759  11  34 <- OPTIMAL
#      0.65    0.9943 0.9810  0.9876 1759  10  34
#      0.70    0.9943 0.9810  0.9876 1759  10  34
# ======================================================================

# %%
# ================================================================
# SEL 18 -- Simpan Model Terbaik, Tokenizer & Metadata Inferensi
# ================================================================
# [FIX Q4] Metadata menyertakan versi library & tanggal training.
# ================================================================
os.makedirs(cfg.output_dir, exist_ok=True)
trainer.model.save_pretrained(cfg.output_dir)
tokenizer.save_pretrained(cfg.output_dir)

metadata_inferensi = {
    "threshold_optimal":     float(THRESHOLD_OPTIMAL),
    "threshold_default":     0.5,
    "metric_for_best_model": "f1",
    "model_name":            cfg.model_name,
    "max_length":            cfg.max_length,
    "label2id":              label_ke_id,
    "id2label":              {str(k): v for k, v in id_ke_label.items()},
    "transformers_version":  transformers.__version__,   # [FIX Q4]
    "torch_version":         torch.__version__,          # [FIX Q4]
    "training_date":         pd.Timestamp.now().strftime("%Y-%m-%d"),  # [FIX Q4]
}
with open(os.path.join(cfg.output_dir, "inference_config.json"), "w",
          encoding="utf-8") as _f:
    _json.dump(metadata_inferensi, _f, indent=2, ensure_ascii=False)

print(f"Model & metadata disimpan ke: {cfg.output_dir}/")
print(f"   Best checkpoint      : {trainer.state.best_model_checkpoint}")
print(f"   THRESHOLD_OPTIMAL    : {THRESHOLD_OPTIMAL:.2f}")
print(f"   transformers_version : {transformers.__version__}  [FIX Q4]")
print(f"   training_date        : {metadata_inferensi['training_date']}  [FIX Q4]")
# Out:
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Model & metadata disimpan ke: indobert_hoax_model_v3/
#    Best checkpoint      : indobert_hoax_model_v3/checkpoint-3507
#    THRESHOLD_OPTIMAL    : 0.62
#    transformers_version : 5.0.0  [FIX Q4]
#    training_date        : 2026-04-10  [FIX Q4]

# %% [markdown]
# ## Inferensi Multi-Paragraf (Sentence-Level + Topic)
#
# **Tidak mengubah training classifier IndoBERT.** Semua proses adalah post-processing:
# memisahkan teks menjadi paragraf dan kalimat, mengklasifikasikan setiap kalimat, mengagregasi label, dan mengekstraksi topik TF-IDF.
#
# - **[FIX HR-1]** Menggunakan `THRESHOLD_OPTIMAL` (dari val set)
# - **[FIX O2]** `torch.inference_mode()` menggantikan `torch.no_grad()`

# %%
# ================================================================
# SEL 20 -- Utilitas Inferensi Multi-Paragraf (Post-Processing)
# ================================================================
# [FIX HR-1] prediksi_batch() pakai THRESHOLD_OPTIMAL (fallback 0.5)
# [FIX O2]   torch.inference_mode() -- lebih efisien dari no_grad
# ================================================================
import re
from collections import defaultdict
from sklearn.feature_extraction.text import TfidfVectorizer

REGEX_PISAH_PARAGRAF = re.compile(r"(?:\r?\n){2,}")
REGEX_PISAH_KALIMAT  = re.compile(r'[^.!?]+(?:[.!?]+(?:[")\]]+)?)|[^.!?]+$')
REGEX_SPASI          = re.compile(r"\s+")
REGEX_TOKEN          = re.compile(r"[a-zA-Z]{3,}")

STOPWORDS_ID = {
    "yang","dan","atau","di","ke","dari","untuk","dengan","pada",
    "adalah","itu","ini","dalam","sebagai","karena","juga","agar",
    "oleh","saat","akan","telah","sudah","tidak","iya","ya","kita",
    "mereka","kami","anda","hingga","lebih","masih","dapat","bisa",
    "setelah","sebelum","tersebut","terhadap","disebut","menurut",
}


def normalisasi_teks(teks: str) -> str:
    return REGEX_SPASI.sub(" ", str(teks)).strip()


def pisahkan_paragraf(teks: str) -> List[str]:
    mentah = str(teks).strip()
    if not mentah: return []
    par = [p.strip() for p in REGEX_PISAH_PARAGRAF.split(mentah) if p.strip()]
    return par if par else [mentah]


def pisahkan_kalimat(paragraf: str) -> List[str]:
    d = normalisasi_teks(paragraf)
    if not d: return []
    kal = [m.group(0).strip() for m in REGEX_PISAH_KALIMAT.finditer(d)]
    return [k for k in kal if k] or [d]


def prediksi_batch(teks_list: List[str], ukuran_batch: int = 64) -> List[Dict]:
    if not teks_list: return []
    th = THRESHOLD_OPTIMAL if "THRESHOLD_OPTIMAL" in globals() else 0.5
    semua_probs = []
    model.eval()
    for i in range(0, len(teks_list), ukuran_batch):
        potongan = [normalisasi_teks(t) or "[EMPTY]" for t in teks_list[i:i+ukuran_batch]]
        enc = tokenizer(potongan, truncation=True, max_length=cfg.max_length,
                        padding=True, return_tensors="pt")
        enc = {k: v.to(device) for k, v in enc.items()}
        with torch.inference_mode():   # [FIX O2]
            probs = torch.softmax(model(**enc).logits, dim=-1).cpu().numpy()
        semua_probs.extend(probs)

    hasil = []
    for baris in semua_probs:
        p_n, p_h = float(baris[0]), float(baris[1])
        label = "hoax" if p_h >= th else "not_hoax"
        conf  = max(p_h, p_n)
        warna = "red" if label=="hoax" else ("amber" if conf<0.70 else "green")
        hasil.append({
            "label": label,
            "probabilities": {"not_hoax": round(p_n,6), "hoax": round(p_h,6)},
            "hoax_probability": round(p_h, 6),
            "confidence":       round(conf, 6),
            "color":            warna,
            "threshold_used":   round(th, 2),
        })
    return hasil


def ekstrak_topik_tfidf(teks_par: List[str], top_k: int = 3, maks_fitur: int = 1500) -> List[Dict]:
    if not teks_par: return []
    vec = TfidfVectorizer(lowercase=True, ngram_range=(1,2), max_features=maks_fitur,
                           token_pattern=r"(?u)\b[a-zA-Z][a-zA-Z]+\b",
                           stop_words=list(STOPWORDS_ID))
    out_t = []
    try:
        M = vec.fit_transform(teks_par); F = vec.get_feature_names_out()
        for i in range(M.shape[0]):
            br = M.getrow(i)
            if br.nnz == 0:
                tok = [t for t in REGEX_TOKEN.findall(teks_par[i].lower()) if t not in STOPWORDS_ID]
                kk  = list(dict.fromkeys(tok))[:top_k] or ["topik_umum"]
                skor = 0.0
            else:
                pas  = sorted(zip(br.indices, br.data), key=lambda x:(-x[1],F[x[0]]))[:top_k]
                kk   = [F[idx] for idx,_ in pas]
                skor = float(np.mean([v for _,v in pas])) if pas else 0.0
            out_t.append({"label": " / ".join(kk[:2]) if kk else "topik_umum",
                           "score": round(skor,6), "keywords": kk[:top_k]})
    except Exception:
        for t in teks_par:
            tok = [x for x in REGEX_TOKEN.findall(t.lower()) if x not in STOPWORDS_ID]
            kk  = list(dict.fromkeys(tok))[:top_k] or ["topik_umum"]
            out_t.append({"label": " / ".join(kk[:2]) if kk else "topik_umum",
                           "score": 0.0, "keywords": kk[:top_k]})
    return out_t


def analisis_multi_paragraf(teks: str, ukuran_batch_kalimat: int = 64) -> Dict[str,Any]:
    teks_m = str(teks).strip()
    th = THRESHOLD_OPTIMAL if "THRESHOLD_OPTIMAL" in globals() else 0.5
    if not teks_m:
        return {"document":{"label":"not_hoax","hoax_probability":0.0,"confidence":0.0,
                             "risk_level":"low","sentence_aggregate_label":"not_hoax",
                             "threshold_used":th,
                             "summary":{"paragraph_count":0,"sentence_count":0,
                                        "hoax_sentence_count":0,"not_hoax_sentence_count":0}},
                "paragraphs":[],"shared_topics":[]}

    pred_doc = prediksi_batch([teks_m], ukuran_batch=1)[0]
    par_list = pisahkan_paragraf(teks_m)
    t_kal, p_kal = [], []
    for pi, par in enumerate(par_list):
        for si, k in enumerate(pisahkan_kalimat(par)):
            t_kal.append(k); p_kal.append((pi,si))

    pred_kal = prediksi_batch(t_kal, ukuran_batch=ukuran_batch_kalimat)
    obj_par  = [{"paragraph_index":i,"text":p,"sentences":[]} for i,p in enumerate(par_list)]
    for (pi,si),tk,pred in zip(p_kal,t_kal,pred_kal):
        obj_par[pi]["sentences"].append({"sentence_index":si,"text":tk,**pred})

    topik_list = ekstrak_topik_tfidf([p["text"] for p in obj_par])
    jh = jnh = 0
    for i,op in enumerate(obj_par):
        kal = op["sentences"]
        if not kal:
            op.update({"label":"not_hoax","hoax_probability":0.0,"confidence":0.0})
        else:
            op["label"]            = "hoax" if any(k["label"]=="hoax" for k in kal) else "not_hoax"
            op["hoax_probability"] = round(max(k["hoax_probability"] for k in kal),6)
            op["confidence"]       = round(max(k["confidence"]       for k in kal),6)
            jh  += sum(1 for k in kal if k["label"]=="hoax")
            jnh += sum(1 for k in kal if k["label"]!="hoax")
        op["topic"] = topik_list[i]

    tmap = defaultdict(list)
    for p in obj_par: tmap[p["topic"]["label"]].append(p["paragraph_index"])
    topik_bersama = sorted([{"label":l,"paragraph_indices":v} for l,v in tmap.items() if len(v)>1],
                            key=lambda x:(x["paragraph_indices"][0],x["label"]))

    return {
        "document": {
            "label":                    pred_doc["label"],
            "hoax_probability":         pred_doc["hoax_probability"],
            "confidence":               pred_doc["confidence"],
            "threshold_used":           pred_doc["threshold_used"],
            "risk_level": ("high" if pred_doc["hoax_probability"]>0.98 else
                           "medium" if pred_doc["hoax_probability"]>0.60 else "low"),
            "sentence_aggregate_label": "hoax" if jh>0 else "not_hoax",
            "summary":{"paragraph_count":len(obj_par),"sentence_count":len(pred_kal),
                        "hoax_sentence_count":jh,"not_hoax_sentence_count":jnh},
        },
        "paragraphs":obj_par, "shared_topics":topik_bersama,
    }


print("Utilitas inferensi multi-paragraf siap.")
print(f"   Threshold aktif  : {THRESHOLD_OPTIMAL:.2f}  [FIX HR-1]")
print(f"   Inference context: torch.inference_mode()  [FIX O2]")
# Out:
# Utilitas inferensi multi-paragraf siap.
#    Threshold aktif  : 0.62  [FIX HR-1]
#    Inference context: torch.inference_mode()  [FIX O2]

# %% [markdown]
# ## Demo Inferensi V1
#
# Deteksi multi-paragraf dengan threshold yang sudah dikalibrasi.

# %%
# ================================================================
# SEL 21 -- Demo Inferensi Multi-Paragraf
# ================================================================
contoh_teks = """
Beredar unggahan media sosial yang menyebut pemerintah membagikan bantuan tunai langsung tanpa syarat lewat tautan tertentu. Banyak akun meminta warga mengisi data pribadi dan OTP agar dana cair hari itu juga.

Kementerian terkait kemudian merilis klarifikasi bahwa informasi tersebut tidak benar dan meminta masyarakat tidak membagikan tautan yang tidak berasal dari kanal resmi. Warga diminta cek pengumuman hanya lewat situs resmi pemerintah.

Sejumlah komentar pengguna juga menuliskan pengalaman bahwa tautan serupa berujung pada permintaan data rekening. Pakar keamanan digital menyarankan verifikasi sumber sebelum menyebarkan pesan berantai.
"""

hasil = analisis_multi_paragraf(contoh_teks, ukuran_batch_kalimat=64)

print("=" * 60 + "\nHASIL DOKUMEN:")
for k, v in hasil["document"].items():
    if k != "summary": print(f"  {k:30s}: {v}")
print(f"  {'summary':30s}: {hasil['document']['summary']}")
print("=" * 60)

for par in hasil["paragraphs"]:
    print(f"\n[Paragraf {par['paragraph_index']}]  label={par['label']}")
    print(f"  Topik : {par['topic']['label']} (score={par['topic']['score']})")
    for k in par["sentences"]:
        print(f"  . ({k['sentence_index']}) {k['label']} | p_hoax={k['hoax_probability']:.4f} | conf={k['confidence']:.4f}")

if hasil["shared_topics"]:
    print("\nTopik Bersama:", hasil["shared_topics"])
# Out:
# ============================================================
# HASIL DOKUMEN:
#   label                         : hoax
#   hoax_probability              : 0.719137
#   confidence                    : 0.719137
#   threshold_used                : 0.62
#   risk_level                    : medium
#   sentence_aggregate_label      : hoax
#   summary                       : {'paragraph_count': 3, 'sentence_count': 6, 'hoax_sentence_count': 6, 'not_hoax_sentence_count': 0}
# ============================================================
#
# [Paragraf 0]  label=hoax
#   Topik : akun / akun meminta (score=0.14461)
#   . (0) hoax | p_hoax=0.9748 | conf=0.9748
#   . (1) hoax | p_hoax=0.9999 | conf=0.9999
#
# [Paragraf 1]  label=hoax
#   Topik : resmi / bahwa informasi (score=0.196977)
#   . (0) hoax | p_hoax=0.9999 | conf=0.9999
#   . (1) hoax | p_hoax=0.9989 | conf=0.9989
#
# [Paragraf 2]  label=hoax
#   Topik : bahwa tautan / berantai (score=0.1591)
#   . (0) hoax | p_hoax=0.9992 | conf=0.9992
#   . (1) hoax | p_hoax=0.9929 | conf=0.9929

# %% [markdown]
# ## No-Regression Guarantee
#
# 1. **Training core tidak diubah secara semantik** -- alur `70/15/15 split -> balancing hanya di train -> classifier biner IndoBERT` identik dengan baseline.
# 2. **BERTopic murni post-processing** -- tidak menyentuh bobot model classifier.
# 3. **Semua perbaikan bersifat additive** -- bug fix + optimasi tanpa mengganti arsitektur.
# 4. **Threshold dikalibrasi dari val set** -- test set tidak disentuh sampai evaluasi akhir.

# %% [markdown]
# ## BERTopic Topic Modeling (Post-Training)
#
# Berjalan **setelah** training classifier selesai. Tidak masuk ke loop training.
#
# **Perbaikan aktif:**
# - **[FIX MR-2]** Corpus = `train_df_pra_oversampling` (bebas duplikat)
# - **[FIX MR-3]** `calculate_probabilities=False` -- fit 2-3x lebih cepat
# - **[FIX LR-4]** `sentence_embedder` dihapus dari GPU setelah encoding
# - **[FIX Q3]** `nr_topics="auto"` -- merge micro-topik otomatis
# - **[FIX B1]** Regex pisah paragraf diperbaiki: `r"(?:\r?\n){2,}"`
# - **[A3]** Analisis topik per label hoax/non-hoax ditambahkan

# %%
# ================================================================
# SEL 23 -- Import Stack BERTopic
# ================================================================
from bertopic import BERTopic
from sentence_transformers import SentenceTransformer
from umap import UMAP
from hdbscan import HDBSCAN
from sklearn.feature_extraction.text import CountVectorizer
import re as _re
print("Import BERTopic stack selesai.")
# Out:
# Import BERTopic stack selesai.

# %%
# ================================================================
# SEL 24 -- Fit BERTopic pada Korpus Training (Post-Training)
# ================================================================
# [FIX MR-2] Corpus pra-oversampling (bebas duplikat)
# [FIX MR-3] calculate_probabilities=False
# [FIX LR-4] Hapus embedder dari GPU setelah encoding
# [FIX Q3]   nr_topics="auto"
# ================================================================

if not AKTIFKAN_BERTOPIC:
    model_topik = None; dokumen_topik = []; id_topik = []; prob_topik = None
    print("AKTIFKAN_BERTOPIC=False, proses BERTopic dilewati.")
else:
    # [FIX MR-2]
    dokumen_topik = train_df_pra_oversampling["text"].astype(str).tolist()
    if MAKS_DOKUMEN_BERTOPIC and len(dokumen_topik) > MAKS_DOKUMEN_BERTOPIC:
        rng = random.Random(SEED_BERTOPIC)
        dokumen_topik = rng.sample(dokumen_topik, MAKS_DOKUMEN_BERTOPIC)

    print(f"Dokumen BERTopic (pra-oversampling): {len(dokumen_topik):,}  [FIX MR-2]")
    dev = "cuda" if torch.cuda.is_available() else "cpu"
    if torch.cuda.is_available():
        print(f"VRAM sebelum encode: {torch.cuda.memory_allocated()/1e6:.1f} MB")

    embedder = SentenceTransformer(MODEL_EMBEDDING_BERTOPIC, device=dev)
    emb = embedder.encode(
        dokumen_topik, batch_size=UKURAN_BATCH_EMBED,
        show_progress_bar=True, convert_to_numpy=True, normalize_embeddings=True,
    )
    print(f"Shape embeddings: {emb.shape}")

    # [FIX LR-4] Hapus embedder segera setelah encoding
    del embedder; gc.collect()
    if torch.cuda.is_available():
        torch.cuda.empty_cache()
        print(f"VRAM setelah hapus embedder: {torch.cuda.memory_allocated()/1e6:.1f} MB  [FIX LR-4]")

    umap_m = UMAP(n_neighbors=15, n_components=5, min_dist=0.0, metric="cosine",
                   random_state=SEED_BERTOPIC, low_memory=True)
    hdb_m  = HDBSCAN(min_cluster_size=15, metric="euclidean",
                      cluster_selection_method="eom", prediction_data=True)
    vec_m  = CountVectorizer(ngram_range=(1,2), min_df=5)

    # [FIX MR-3] calculate_probabilities=False  [FIX Q3] nr_topics="auto"
    model_topik = BERTopic(
        language                 = "multilingual",
        calculate_probabilities  = BERTOPIC_HITUNG_PROB,
        nr_topics                = NR_TOPIK,
        seed_topic_list          = daftar_tema_utama if AKTIFKAN_GUIDED else None,  # [V3]
        verbose                  = True,
        embedding_model          = None,
        umap_model               = umap_m,
        hdbscan_model            = hdb_m,
        vectorizer_model         = vec_m,
    )
    id_topik, prob_topik = model_topik.fit_transform(dokumen_topik, emb)

    info = model_topik.get_topic_info()
    n_valid = len(info[info["Topic"] != -1])
    print(f"\nBERTopic selesai.")
    print(f"   Topik valid : {n_valid}")
    print(f"   Outlier (-1): {sum(1 for t in id_topik if t==-1):,}")
    print("\n10 topik teratas:")
    print(info.head(10).to_string(index=False))
# Out:
# Dokumen BERTopic (pra-oversampling): 120,521  [FIX MR-2]
# VRAM sebelum encode: 1347.6 MB
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/645 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/471M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json:   0%|          | 0.00/526 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Batches:   0%|          | 0/3767 [00:00<?, ?it/s]
# Shape embeddings: (120521, 384)
# 2026-04-10 12:44:43,188 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# VRAM setelah hapus embedder: 1347.6 MB  [FIX LR-4]
# 2026-04-10 12:47:55,548 - BERTopic - Dimensionality - Completed ✓
# 2026-04-10 12:47:55,553 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2026-04-10 12:48:12,160 - BERTopic - Cluster - Completed ✓
# 2026-04-10 12:48:12,161 - BERTopic - Representation - Extracting topics using c-TF-IDF for topic reduction.
# 2026-04-10 12:48:36,929 - BERTopic - Representation - Completed ✓
# 2026-04-10 12:48:36,941 - BERTopic - Topic reduction - Reducing number of topics
# 2026-04-10 12:48:37,851 - BERTopic - Representation - Fine-tuning topics using representation models.
# 2026-04-10 12:49:03,730 - BERTopic - Representation - Completed ✓
# 2026-04-10 12:49:03,762 - BERTopic - Topic reduction - Reduced number of topics from 736 to 611
# BERTopic selesai.
#    Topik valid : 610
#    Outlier (-1): 54,307
#
# 10 topik teratas:
#  Topic  Count                                           Name                                                                                                                        Representation                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
#     -1  54307                 -1_presiden_partai_jakarta_dpr                                                [presiden, partai, jakarta, dpr, korban, kata, indonesia, pemerintah, negara, menteri]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [jakarta kompas com presiden ri joko widodo jokowi menginginkan pilkada jakarta mengulang kesuksesan pilpres pilpres pasangan prabowo subianto gibran rakabuming raka memperoleh persen suara meski menargetkan perolehan sebesar persen pilpres bayangan persen dapatnya persen ujar jokowi memberikan sambutan pertemuan cempaka putih jakarta pusat senin mencapai tujuan jokowi berharap partai pengusung hingga relawan bekerja keras memenangkan ridwan kamil suswono pilkada jakarta kalau gerakannya masif benar semuanya berusaha kota jakarta cintai kayak pilpres kata jokowi arahan jokowi disambut relawan ikut hadir tengah tamu undangan satu putaran siap perintah pak teriak satu pria sisi kanan panggung jokowi sempat terdiam sejenak mendengar permintaan selang beberapa jokowi melanjutkan sambutan jokowi meminta kader koalisi indonesia maju kim plus bekerja ekstra keras masa kampanye pilkada jakarta sekarang tinggal bapak ibu semuanya saudara saudara semuanya bergerak waktu sangat sempit kata jokowi s ...
#      0   2364              0_partai_koalisi_anies_ketua umum                                                   [partai, koalisi, anies, ketua umum, pks, ketua, demokrat, capres, pilpres, nasdem]                                               [jakarta kompas com bakal calon gubernur jakarta ridwan kamil rk menargetkan dirinya bakal calon wakil gubernur pasangannya suswono menang satu putaran pilkada jakarta rk menyebut koalisi indonesia maju kim plus meminta suswono memenangi pilkada perolehan suara besar kim plus beranggotakan belasan partai politik target diminta menang satu putaran pilkada jakarta menangnya jangan menang tipis mewakili harkat martabat besarnya koalisi ujar ridwan kamil hutan kota gbk plataran senayan tanah abang jakarta pusat senin meski rk enggan mengungkapkan strategi khusus digunakan dirinya suswono menarik perhatian pemilih termasuk menggaet pendukung mantan gubernur jakarta anies baswedan menyampaikan pesan bertemu dulu melulu ujungnya meminta dukungan lebih menghargai pemimpin pemimpin jakarta keilmuannya tentunya butuhkan terpilih kata ridwan kamil menambahkan kim plus tengah melakukan finalisasi struktur tim pemenangan rk suswono pilkada jakarta meski memerinci anggota tim sukses ketua harian dpp partai gerindra sufmi dasco ahmad dipastikan bakal menjadi ketua dewan pembina nantinya dasco memberikan berbagai arahan terkait pemenangan target hingga strategi digunakan kampanye rk suswono kebetulan timses rido pak dasco menjadi ketua dewan pembina kata ridwan kamil kendati ridwan kamil bilang upaya pemenangan dirinya suswono bukan dilakukan tim sukses anggota legislatif partai anggota kim plus terpilih pemilu intinya semua partai anggota anggota dprd bergerak turun konstituennya mengampanyekan visi misi kekuatan pasangan rido kata diketahui ridwan kamil suswono merupakan bakal pasangan calon gubernur wakil gubernur pilkada jakarta ridwan kamil merupakan kader partai golkar suswono ketua majelis pertimbangan partai keadilan sejahtera pks keduanya diusung kim plus koalisi partai partai mendukung prabowo subianto gibran rakabuming raka pemilihan presiden kim plus terdiri partai gerindra partai golkar partai solidaritas indonesia psi partai demokrat partai amanat nasional pan partai garuda partai gelora partai rakyat adil makmur prima pks partai nasdem partai kebangkitan bangsa pkb partai perindo partai persatuan pembangunan pp partai kebangkitan nusantara pkn adapun tahapan pilkada memasuki masa kampanye september hingga november hari pemungutan suara digelar serentak seluruh indonesia november, tempo co jakarta sekretaris jenderal partai demokrasi indonesia perjuangan pdip hasto kristiyanto menyiratkan sinyal partainya berkoalisi partai nasdem partai pimpinan surya paloh menjalin komunikasi intensif pks merekomendasikan gubernur dki jakarta anies baswedan salah satu bakal capres pilpres pdi perjuangan suka mengganggu rumah tangga partai politik pelaksanaan rakernas melihat bagaimana nasdem melakukan pertemuan sangat intens partai politik bahkan kemudian pks kemudian rakernas nasdem kan mayoritasnya memberikan preferensi pak anies calon presiden ujar hasto kamis juli baca gentar anies baswedan pks gerindra depok prabowo negarawan dicintai rakyat hasto mengatakan partainya menghormati langkah langkah organisatoris partai melakukan manuver menjelang pilpres ujar pdip terlibat mengganggu hubungan tersebut silahturahmi antarketua umum partai politik disampaikan berbagai rilis kan mengarah bentuk kerja sama partai politik dihormati pdip suatu sangat bagus mengganggu suatu kemapanan kerja sama dibangun tuturnya hasto mengungkap lima aspek utama menjadi pertimbangan partainya membangun kerja sama partai politik pilpres aspek ideologis historis platform partai agenda strategis masa depan menimbang etika politik baca dukung ganjar jadi capres pan baru tahap mendorong tarik kader ideologi histori platform hasto menyebut partai banteng memiliki kedekatan lima partai partai gerindra partai golkar partai kebangkitan ban ...
#      1   2331                  1_kpk_korupsi_jaksa_tersangka                                                       [kpk, korupsi, jaksa, tersangka, hakim, pengadilan, pt, kasus, perkara, pidana]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      [jakarta kompas com sekretaris jenderal sekjen partai demokrasi indonesia perjuangan pdi hasto kristiyanto meminta komisi pemberantasan korupsi kpk pandang bulu menegakkan hukum disampaikan hasto usai ditahan komisi antirasuah terkait kasus dugaan perintangan penyidikan kasus dugaan suap menjerat eks anggota legislatif pdi harun masiku hasto meminta kpk berani mengungkap berbagai kasus korupsi termasuk melakukan pemeriksaan keluarga presiden ri joko widodo semoga menjadi momentum komisi pemberantasan korupsi menegakkan hukum termasuk memeriksa keluarga pak jokowi kata hasto dibawa rumah tahanan kpk kamis hasto menuturkan posisinya sekjen partai memiliki konsekuensi politik termasuk dikriminalisasi mengaku kaget penahanan dilakukan kpk sejak awal katakan sekjen pdi perjuangan kepala tegak siap menerima konsekuensi apapun indonesia raya indonesia dibangun pengorbanan jiwa raga negeri pejuang kata hasto pernah menyesal terus berjuang api semangat menyala nyala imbuh hasto  ...
#      2   1881          2_virus_virus corona_corona_meninggal                    [virus, virus corona, corona, meninggal, positif, corona indonesia, positif corona, pasien, corona meninggal, pdp]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
#      3   1487                        3_banjir_hujan_bmkg_air                                                           [banjir, hujan, bmkg, air, cuaca, angin, wilayah, gelombang, bpbd, berawan]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               [jakarta kompas com badan meteorologi klimatologi geofisika bmkg menyebut wilayah jabodetabek berpotensi hujan meski memasuki awal musim kemarau direktur meteorologi publik bmkg andri ramdhani menjelaskan awal musim kemarau wilayah jabodetabek diperkirakan dimulai sejak dasarian pertama mei hingga awal juni kondisi atmosfer dinamis menyebabkan cuaca sejumlah wilayah dipengaruhi hujan bulan mei umum berada masa peralihan musim hujan kemarau ditandai cuaca panas pagi hingga siang hari potensi hujan sore malam hari ujar andri keterangannya minggu beberapa hari terakhir wilayah jakarta bekasi depok dilanda hujan deras disertai angin kencang bmkg mencatat kondisi salah satunya dipengaruhi keberadaan sistem bibit siklon tropis terpantau sejak mei pukul wib perairan selatan jawa tengah sistem be ...
#      4   1451  4_whatsapp_akun whatsapp_akun_mengatasnamakan                     [whatsapp, akun whatsapp, akun, mengatasnamakan, pesan, counter penjelasan, penipuan, hoaks, beredar, hoaks link]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
#      5   1222              5_pesawat_bandara_penerbangan_jet                                           [pesawat, bandara, penerbangan, jet, maskapai, udara, penumpang, jet pribadi, balon, pilot] [baca berita sedikit iklan klik sini tempo co jakarta penerbangan bandara halim perdanakusuma dipindahkan bandara soekarno hatta mulai agustus pihak bandara soekarno hatta menyatakan siap menampung sebagian penerbangan bandara halim perdanakusuma dipindahkan bandara cengkareng baca berita sedikit iklan klik sini kalau persiapan dinyatakan sangat siap kata general manager pt angkasa pura indonesia kantor cabang bandara internasional soekarno hatta dwi ananda wicaksana kamis juli scroll bawah melanjutkan membaca baca berita sedikit iklan klik sini dwi mengatakan terdapat persen penerbangan bandara halim perdanakusuma pindah bandara soekarno hatta dwi menjelaskan maskapai pindah diseleksi dipastikan rute sama pindah jadi penyesuaian penyesuaian bandara soekarno hatta mengaku kondisi tersebut bukan pertama kalinya terjadi sebelumnya bandara halim pernah ditutup total seluruh penerbangan dipindah soekarno hatta flight dipindah semua soekarno hatta berlangsung baik ujarnya dwi mengungkapkan pengelola bandara soekarno hatta menyeleksi penerbangan dipindahkan cengkareng segala persiapan terkait peralihan penerbangan sangat siap melayani rute halim pindah bandara soekarno hatta agustus seiring rencana pemindahan sebagian penerbangan bandara halim cengkareng dwi menginformasikan pengelola bandara soekarno hatta mengoperasikan terminal ic selesai direvitalisasi agustus citilink pindah memang mungkin bertahap kontrak baru finish oktober ujarnya bandara halim perdanakusuma merupakan bandara internasional berlokasi jakarta indonesia bandara tersebut difungsikan markas komando operasi angkatan udara koops au tni au digunakan penerbangan komersial layani penumpang bandara halim perdanakusuma mulai beroperasi menjadi bandara komersial sejak januari ketetapan tersebut disahkan bandara internasional soekarno hatta dinilai penuh sesak bandara bernama lapangan tebrang cililitan tersebut mulai mengalihkan sejumlah penerbangan komersil bandara internasional soekarno hatta abad daerah cililitan merupakan lokasi bandara halim perdanakusuma merupakan tanah partikelir dimiliki pieter van der velde informasi angkasapura co id tanah tersebut diberi nama tandjoeng ost sebagian tanah dialih fungsikan menjadi sebuah lapangan terbang pertama kota batavia fungsinya pangkalan militer bandara tersebut digunakan bandar udara sipil utama kota jakarta bersamaan kemayoran tahun bandar udara berbagi penerbangan internasional kemayoran padatnya jadwal penerbangan sana bandara halim perdanakusuma diamanahkan menggantikan bandara kemayoran semakin padat justru tertuju pembangunan bandar udara baru daerah cengkareng bandar udara bernama bandar udara internasional soekarno hatta usai bandara kemayoran ditutup bandara halim perdanakusuma mulai mengurangi jadwal penerbangan sipil fokus kepentingan militer halim memberikan slot jam penerbangan berjadwal domestik maupun internasional bertujuan mengurangi padatnya jadwal penerbangan pilihan editor mulai agustus persen penerbangan bandara halim perdanakusumah pindah soekarno hatta, baca berita sedikit iklan klik sini tempo co jakarta sebanyak bandara dikelola injourney airports siap menyambut penumpang pesawat arus balik lebaran direktur utama injourney airports faik fahmi memastikan kesiapan titik layanan baik area keberangkatan maupun kedatangan seluruh proses bandara berjalan baik baca berita sedikit iklan klik sini area keberangkatan penumpang pesawat titik layanan menjadi fokus kelancaran akses kendaraan menuju terminal mengantar penumpang scroll bawah melanjutkan membaca baca berita sedikit iklan klik sini lalu lintas kendaraan bandara termasuk akses menuju terminal sangat penting melakukan peningkatan fasilitas sejumlah bandara bandara gusti ngurah rai bali dilakukan penambahan lajur jalan penambahan akses menuju gedung parkir la ...
#      6    923 6_pandemi_pandemi corona_tengah pandemi_corona [pandemi, pandemi corona, tengah pandemi, corona, corona pandemi, tengah, selama pandemi, pandemi covid, masa pandemi, pandemi virus]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
#      7    914        7_jiwasraya_jangan_nikita mirzani_bikin                                        [jiwasraya, jangan, nikita mirzani, bikin, mirzani, nikita, erick thohir, erick, thohir, kamu]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
#      8    873  8_polisi_polisi tangkap_polisi polisi_tangkap         [polisi, polisi tangkap, polisi polisi, tangkap, ditangkap polisi, ditangkap, ditembak, polisi tembak, ditembak polisi, pria]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...

# %%
# ================================================================
# SEL 25 -- Visualisasi Distribusi Topik & Analisis per Label [A3]
# ================================================================
if AKTIFKAN_BERTOPIC and model_topik is not None:
    info_viz   = model_topik.get_topic_info()
    info_valid = info_viz[info_viz["Topic"] != -1].copy()

    # Plot 1: Top-N topik berdasarkan jumlah dokumen
    if len(info_valid) > 0:
        top_n  = min(15, len(info_valid))
        df_viz = info_valid.nlargest(top_n, "Count")
        plt.figure(figsize=(10, 5))
        plt.barh([str(n)[:45] for n in df_viz["Name"]], df_viz["Count"],
                  color=plt.cm.tab20(np.linspace(0,1,len(df_viz))))
        plt.xlabel("Jumlah Dokumen"); plt.ylabel("Topik")
        plt.title(f"Top {top_n} Topik BERTopic -- Seluruh Corpus",
                  fontsize=12, fontweight="bold")
        plt.gca().invert_yaxis(); plt.tight_layout()
        plt.savefig("distribusi_topik_bertopic.png", dpi=150, bbox_inches="tight")
        plt.show()
        print("Grafik distribusi topik disimpan: distribusi_topik_bertopic.png")

    # [A3] Analisis topik per label hoax/non-hoax
    df_analisis = train_df_pra_oversampling[["text","label"]].copy()
    n_cocok = min(len(df_analisis), len(id_topik))
    df_analisis = df_analisis.iloc[:n_cocok].copy()
    df_analisis["topic_id"] = id_topik[:n_cocok]
    df_analisis = df_analisis[df_analisis["topic_id"] != -1]

    if len(df_analisis) > 0 and len(info_valid) > 0:
        peta_nama = dict(zip(info_valid["Topic"], info_valid["Name"]))
        df_analisis["topic_name"] = df_analisis["topic_id"].map(peta_nama)
        top_k_a = min(10, len(info_valid))

        fig, axes = plt.subplots(1, 2, figsize=(16, 5))
        fig.suptitle("Distribusi Topik per Label -- [A3]", fontsize=13, fontweight="bold")

        for ax, lbl, judul, warna in [
            (axes[0], 0, "Topik Dominan -- Non-Hoax", "#16A34A"),
            (axes[1], 1, "Topik Dominan -- Hoax",     "#DC2626"),
        ]:
            subset = df_analisis[df_analisis["label"]==lbl]
            if len(subset) == 0:
                ax.text(0.5, 0.5, "Tidak ada data", ha="center"); continue
            hitung = subset["topic_name"].value_counts().head(top_k_a)
            ax.barh(hitung.index.str[:40], hitung.values, color=warna, alpha=0.85)
            ax.set_title(judul, fontsize=11, fontweight="bold")
            ax.set_xlabel("Jumlah Dokumen")
            ax.invert_yaxis(); ax.grid(axis="x", alpha=0.3)

        plt.tight_layout()
        plt.savefig("topik_per_label.png", dpi=150, bbox_inches="tight")
        plt.show()
        print("Analisis topik per label disimpan: topik_per_label.png  [A3]")
else:
    print("Model BERTopic belum tersedia, visualisasi dilewati.")
# Out:
# Grafik distribusi topik disimpan: distribusi_topik_bertopic.png
# Analisis topik per label disimpan: topik_per_label.png  [A3]

# %% [markdown]
# ## Evaluasi c-TF-IDF BERTopic [SEL 25b]
#
# Menampilkan hasil kuantitatif topic modeling:
# - Jumlah topik valid & persentase outlier
# - Distribusi dokumen per topik
# - Top-10 kata per topik beserta skor c-TF-IDF
# - Heatmap skor c-TF-IDF (top-5 kata × semua topik)
# - Ekspor CSV untuk lampiran skripsi

# %%
# ================================================================
# SEL 25b -- Evaluasi c-TF-IDF BERTopic  [OOM-SAFE]
# ================================================================
# Perbaikan OOM:
#   1. plt.close() setelah setiap figure — bebaskan memori matplotlib
#   2. Heatmap dibatasi: maks 15 topik × 5 kata unik per topik
#   3. annot dinonaktifkan jika matriks > 200 cell (cegah ribuan Text obj)
#   4. figsize di-cap keras (maks 20×14 inci)
#   5. gc.collect() + torch.cuda.empty_cache() setelah render heatmap
#   6. get_topics() dihapus (tidak dipakai, buang memori)
# ================================================================
if AKTIFKAN_BERTOPIC and model_topik is not None:
    info_topik      = model_topik.get_topic_info()
    id_topik_arr    = np.array(id_topik)
    info_valid_eval = info_topik[info_topik["Topic"] != -1].copy()
    jumlah_topik_valid = len(info_valid_eval)
    jumlah_outlier     = int((id_topik_arr == -1).sum())

    print("=" * 65)
    print("  Evaluasi c-TF-IDF BERTopic  [OOM-SAFE]")
    print("=" * 65)
    print(f"Topik valid       : {jumlah_topik_valid}")
    print(f"Total dokumen     : {len(dokumen_topik):,}")
    print(f"Dokumen outlier   : {jumlah_outlier:,}  ({jumlah_outlier/len(dokumen_topik)*100:.1f}%)")

    # --- Distribusi dokumen per topik ---
    print("\n--- Distribusi Dokumen per Topik ---")
    print(info_valid_eval[["Topic", "Count", "Name"]].to_string(index=False))

    tinggi_bar = min(max(4, jumlah_topik_valid * 0.4), 14)  # cap 14 inci
    fig, ax = plt.subplots(figsize=(8, tinggi_bar))
    bar_colors = plt.cm.tab20(np.linspace(0, 1, len(info_valid_eval)))
    ax.barh(
        [f"T{r['Topic']}: {str(r['Name'])[:40]}" for _, r in info_valid_eval.iterrows()],
        info_valid_eval["Count"].values,
        color=bar_colors,
    )
    ax.set_xlabel("Jumlah Dokumen")
    ax.set_title("Distribusi Dokumen per Topik (c-TF-IDF)", fontweight="bold")
    ax.invert_yaxis(); plt.tight_layout()
    plt.savefig("ctfidf_distribusi_topik.png", dpi=120, bbox_inches="tight")
    plt.show(); plt.close(); gc.collect()  # [OOM-FIX 1]
    print("Grafik disimpan: ctfidf_distribusi_topik.png")

    # --- Kata penting per topik (c-TF-IDF) ---
    print("\n--- Kata Penting per Topik (Top-10, c-TF-IDF) ---")
    baris_ctfidf = []
    for _, baris_info in info_valid_eval.iterrows():
        t_id       = int(baris_info["Topic"])
        nama_topik = str(baris_info["Name"])
        kata_skor  = model_topik.get_topic(t_id) or []
        for rank, (kata, skor) in enumerate(kata_skor[:10], start=1):
            baris_ctfidf.append({
                "Topik_ID"   : t_id,
                "Nama_Topik" : nama_topik[:35],
                "Rank"       : rank,
                "Kata"       : kata,
                "Skor_cTFIDF": round(float(skor), 6),
            })
    df_ctfidf = pd.DataFrame(baris_ctfidf)
    print(df_ctfidf.to_string(index=False))
    df_ctfidf.to_csv("evaluasi_ctfidf_topik.csv", index=False, encoding="utf-8-sig")
    del baris_ctfidf; gc.collect()  # [OOM-FIX 2]
    print("\nHasil c-TF-IDF disimpan: evaluasi_ctfidf_topik.csv")

    # --- Heatmap skor c-TF-IDF  [OOM-SAFE] ---
    # Batasi ke maks 15 topik (terbesar) × top-5 kata unik per topik
    MAKS_TOPIK_HEATMAP = 15
    if jumlah_topik_valid > 0:
        info_heatmap = info_valid_eval.nlargest(MAKS_TOPIK_HEATMAP, "Count")
        top5_per_topik = {}
        for t_id_k in info_heatmap["Topic"].tolist():
            kt = model_topik.get_topic(int(t_id_k)) or []
            top5_per_topik[f"T{t_id_k}"] = {w: float(s) for w, s in kt[:5]}

        # Kumpulkan kata unik (maks 75 kata)
        semua_kata = list({w for d in top5_per_topik.values() for w in d})[:75]
        n_row = len(semua_kata); n_col = len(top5_per_topik)
        n_cell = n_row * n_col

        df_heatmap = pd.DataFrame(
            {t: [top5_per_topik[t].get(w, 0.0) for w in semua_kata] for t in top5_per_topik},
            index=semua_kata,
        )

        # [OOM-FIX 3] cap figsize keras; nonaktifkan annot jika matriks besar
        lebar_h = min(max(8, n_col * 0.8), 20)
        tinggi_h = min(max(6, n_row * 0.32), 14)
        aktifkan_annot = n_cell <= 200  # annot aman hanya untuk matriks kecil

        fig, ax = plt.subplots(figsize=(lebar_h, tinggi_h))
        sns.heatmap(
            df_heatmap,
            annot=aktifkan_annot,
            fmt=".4f" if aktifkan_annot else "",
            cmap="YlOrRd",
            linewidths=0.2,
            ax=ax,
            annot_kws={"size": 6} if aktifkan_annot else {},
        )
        judul_note = "" if aktifkan_annot else f" (annot dinonaktifkan, {n_cell} cell)"
        ax.set_title(
            f"Heatmap c-TF-IDF — Top-5 Kata × {n_col} Topik{judul_note}",
            fontsize=11, fontweight="bold",
        )
        ax.set_xlabel("Topik"); ax.set_ylabel("Kata")
        plt.tight_layout()
        plt.savefig("ctfidf_heatmap.png", dpi=100, bbox_inches="tight")  # [OOM-FIX 4] dpi 100
        plt.show(); plt.close()  # [OOM-FIX 1]

        # [OOM-FIX 5] bebaskan semua variabel heatmap
        del df_heatmap, top5_per_topik, semua_kata, info_heatmap
        gc.collect()
        if torch.cuda.is_available(): torch.cuda.empty_cache()
        print(f"Heatmap c-TF-IDF disimpan: ctfidf_heatmap.png  (annot={'on' if aktifkan_annot else 'off, matriks terlalu besar'})")
else:
    print("Model BERTopic belum tersedia, evaluasi c-TF-IDF dilewati.")
# Out:
# =================================================================
#   Evaluasi c-TF-IDF BERTopic  [OOM-SAFE]
# =================================================================
# Topik valid       : 610
# Total dokumen     : 120,521
# Dokumen outlier   : 54,307  (45.1%)
#
# --- Distribusi Dokumen per Topik ---
#  Topic  Count                                                                   Name
#      0   2364                                      0_partai_koalisi_anies_ketua umum
#      1   2331                                          1_kpk_korupsi_jaksa_tersangka
#      2   1881                                  2_virus_virus corona_corona_meninggal
#      3   1487                                                3_banjir_hujan_bmkg_air
#      4   1451                          4_whatsapp_akun whatsapp_akun_mengatasnamakan
#      5   1222                                      5_pesawat_bandara_penerbangan_jet
#      6    923                         6_pandemi_pandemi corona_tengah pandemi_corona
#      7    914                                7_jiwasraya_jangan_nikita mirzani_bikin
#      8    873                          8_polisi_polisi tangkap_polisi polisi_tangkap
#      9    869                                          9_breaking_timor_hari ini_ini
#     10    820                                           10_masjid_islam_salat_muslim
#     11    809                                11_pasien_positif corona_corona_positif
#     12    804                                        12_nikah_pernikahan_istri_suami
#     13    795                         13_akun_facebook_akun facebook_mengatasnamakan
#     14    794                                         14_israel_gaza_palestina_hamas
#     15    752                                 15_vaksin_vaksin covid_covid_vaksinasi
#     16    721                                      16_kebakaran_api_terbakar_pemadam
#     17    664                                       17_salat_doa_sidang_imam nahrawi
#     18    664                                       18_gempa_bmkg_tsunami_gempa bumi
#     19    633                                 19_mbg_bergizi_makan bergizi_keracunan
#     20    625                                      20_mobil_driver_parkir_mobil baru
#     21    567                                      21_masker_pakai masker_pakai_kain
#     22    508                                        22_kendaraan_tol_km_lalu lintas
#     23    460                       23_presiden jokowi_video_presiden_video tersebut
#     24    459                                           24_kecelakaan_truk_mobil_tol
#     25    457                                             25_lagu_konser_musik_album
#     26    431                                  26_jamaluddin_hakim_jiwasraya_zuraida
#     27    423                                             27_hewan_burung_sapi_macan
#     28    420                                                28_tarif_as_trump_impor
#     29    408                                    29_kredit_bank_bank mandiri_cicilan
#     30    365                               30_wisata_pariwisata_wisatawan_destinasi
#     31    361                                   31_sekolah_guru_sekolah rakyat_siswa
#     32    359                                        32_korban_uki_jenazah_ditemukan
#     33    346                                33_angel_vanessa angel_vanessa_jennifer
#     34    345                                         34_piala_17_timnas_piala dunia
#     35    340                      35_kereta_penumpang_angkut penumpang_transportasi
#     36    338                         36_psbb_psbb transisi_transisi_longgarkan psbb
#     37    336                                       37_mahasiswa_aksi_ui_demonstrasi
#     38    331                                       38_parkir_transjakarta_jalan_jpo
#     39    323                                           39_liga_liverpool_gol_madrid
#     40    316                                       40_artis_foto_galeri_galeri foto
#     41    312                                          41_pelaku_korban_polisi_metro
#     42    296                                       42_planet_matahari_fenomena_bumi
#     43    283                                  43_meninggal_meninggal dunia_yu_dunia
#     44    280                                     44_hamil_bayi_hamil anak_kehamilan
#     45    264                                      45_corona_wabah corona_wabah_gara
#     46    260                                        46_rusia_ukraina_putin_zelensky
#     47    258                                       47_judi_judi online_online_judol
#     48    249                                         48_film_bioskop_trans tv_trans
#     49    246                                          49_iphone_apple_iphone 16_pro
#     50    231                                        50_jepang_tokyo_kyoto_wisatawan
#     51    231                                        51_pasar_sensus_online_pedagang
#     52    221                                   52_pantai_danau_pantai pantai_cantik
#     53    220                                        53_rokok_cukai_merokok_tembakau
#     54    216                                   54_motogp_mandalika_balapan_pembalap
#     55    215                         55_turnbackhoax_fakta_konten_pemeriksaan fakta
#     56    214                                    56_pilkada_bawaslu_politik uang_kpu
#     57    210                                     57_virus_china_virus corona_corona
#     58    208                                                58_kopi_coffee_kafe_teh
#     59    202              59_video_video tersebut_counter penjelasan_unggahan video
#     60    200                                   60_pajak_spt_bebas pajak_wajib pajak
#     61    198                                           61_sim_esim_ponsel_kartu sim
#     62    197                             62_paus_fransiskus_paus fransiskus_vatikan
#     63    197                                      63_gempa_myanmar_di myanmar_junta
#     64    195                          64_kpk_sekretaris ma_eks sekretaris_komisaris
#     65    193                                 65_haji_jemaah_jemaah haji_ibadah haji
#     66    192                               66_anggaran_rp triliun_triliun_efisiensi
#     67    191                                       67_laut_pagar_pagar laut_nelayan
#     68    191                                   68_viral_virus_jadi viral_viral aksi
#     69    190                                          69_china_natuna_tka china_tka
#     70    190                                 70_listrik_tagihan listrik_tagihan_pln
#     71    189                                 71_kapal_kapal pesiar_pesiar_speedboat
#     72    188                                        72_rapid test_rapid_test_corona
#     73    182                                     73_malaysia_tki_lockdown_singapura
#     74    182                                                    74_ruu_dpr_rkuhp_uu
#     75    181                                75_pangeran_harry_pangeran harry_meghan
#     76    180                             76_korupsi_korupsi rp_kasus korupsi_asabri
#     77    179                                      77_pengunjung_ragunan_monas_satwa
#     78    178                                         78_ikan_nelayan_lele_ikan lele
#     79    176                               79_delpedro_narapidana_tahanan_tersangka
#     80    174                                 80_ihsg_ihsg dibuka_bursa asia_menguat
#     81    173                                       81_kartu pra_pra kerja_pra_kartu
#     82    169                    82_pemerintah_utang pemerintah_utang_pemerintah mau
#     83    168                                            83_pilkada_kpu_psu_mendagri
#     84    165                                        84_siswa_guru_belajar_mahasiswa
#     85    163                           85_investasi_saham_investor_investasi bodong
#     86    161                                       86_buruh_omnibus law_omnibus_law
#     87    160                                            87_pendatang_job_fair_kerja
#     88    159                                        88_lockdown_india_wuhan_langgar
#     89    159                                  89_papua_pemekaran_provinsi papua_dob
#     90    159                                          90_narkoba_sabu_narkotika_bnn
#     91    159                                         91_beras_bulog_ton_harga beras
#     92    156                           92_ekonomi ri_ekonomi_pertumbuhan ekonomi_ri
#     93    153                            93_corona_ekonomi ri_ekonomi_corona ekonomi
#     94    152                                     94_hotel_corona hotel_artotel_sapa
#     95    151                               95_dokter_seksual_rshs_kekerasan seksual
#     96    151                                   96_saudi_arab_arab saudi_saudi setop
#     97    150                                  97_new normal_new_normal_terapkan new
#     98    149                                           98_test_rapid test_rapid_tes
#     99    148                                            99_dolar as_dolar_rupiah_as
#    100    148                                        100_galeri foto_galeri_kue_foto
#    101    147                                 101_video_viral_video call_bikin video
#    102    146                                        102_thailand_turis_bank bjb_bjb
#    103    146                                   103_penumpang_stasiun_kereta_lebaran
#    104    144                                         104_sparks_red sparks_red_voli
#    105    144                                               105_ayam_resep_sup_gurih
#    106    143                                  106_narkoba_lucinta_lucinta luna_luna
#    107    143                                 107_persen_survei_elektabilitas_ganjar
#    108    143                    108_twitter_trending_trending twitter_jadi trending
#    109    142                              109_puasa_ramadhan_berbuka_puasa ramadhan
#    110    140                                         110_film_drama_karakter_cerita
#    111    140                            111_corona_pedagang_tengah corona_pengusaha
#    112    138                                     112_kecelakaan_menabrak_truk_mobil
#    113    137                  113_pemilu_proporsional_sistem proporsional_penundaan
#    114    136                                         114_motor_motogp_yamaha_ducati
#    115    135                                         115_lagu_konser_musik_festival
#    116    133                                         116_gunung_gua_borobudur_dieng
#    117    133                                     117_foto_masjid_video_disinformasi
#    118    130                                     118_pengusaha_bisnis_bayar thr_thr
#    119    130                                          119_gula_harga gula_ton_rp kg
#    120    128                                              120_suap_hakim_arif_vonis
#    121    125                 121_keluarga_ketahanan keluarga_ruu ketahanan_syahrini
#    122    123                                    122_minta maaf_maaf_minta_maaf soal
#    123    123                                          123_saham_indeks_ihsg_menguat
#    124    123                    124_corona_positif corona_positif_penanganan corona
#    125    122                                    125_jurnalis_pers_kepala babi_teror
#    126    121                              126_luar angkasa_angkasa_spacex_astronaut
#    127    121                                          127_tidur_ngantor_alarm_sleep
#    128    121                        128_maaf_meminta maaf_permintaan maaf_maaf atas
#    129    120                         129_corona_cegah_cegah corona_liburkan sekolah
#    130    119                                130_ashraf sinclair_sinclair_ashraf_bcl
#    131    118                                   131_sampah_plastik_lingkungan_limbah
#    132    118                                        132_seks_bercinta_wanita_gairah
#    133    117                              133_surat_surat tersebut_sebuah surat_bkn
#    134    117                                          134_digital_ai_teknologi_data
#    135    117                       135_lowongan_calon karyawan_staff_lowongan kerja
#    136    116                     136_pemakaman_jenazah_dimakamkan_pemakaman jenazah
#    137    115                          137_mobil listrik_listrik_mobil_motor listrik
#    138    115                               138_samsung_galaxy_samsung galaxy_ponsel
#    139    113                                          139_pelajar_siswa_guru_polisi
#    140    111                                    140_youtuber_youtube_channel_konten
#    141    111                                      141_omnibus law_omnibus_law_ketik
#    142    110                                       142_kanker_buah_tumor_makan buah
#    143    110                               143_pangan_stok pangan_stok_harga pangan
#    144    109                                        144_game_switch_konsol_nintendo
#    145    109                                145_perkosa_diperkosa_syifa hadju_hadju
#    146    109                             146_hujan_bmkg_hujan disertai_bmkg waspada
#    147    106                                      147_bansos_gus ipul_ipul_penerima
#    148    106                                        148_kucing_ras_hewan_peliharaan
#    149    105                                       149_whatsapp_photos_fitur_motion
#    150    105                                     150_spbu_bbm_pertamina_spbu swasta
#    151    104                              151_vaksin_corona_vaksin virus_bill gates
#    152    104                              152_telur_kuning telur_matang_telur rebus
#    153    104                         153_masters_daihatsu_apriyani_greysia apriyani
#    154    103                                           154_google_fitur_aplikasi_ai
#    155    102                                    155_minyak_harga minyak_barel_harga
#    156    101                                         156_harga emas_gram_emas_harga
#    157    101                                  157_tutup_ditutup_corona_cegah corona
#    158    100                               158_iuran bpjs_bpjs_bpjs kesehatan_iuran
#    159    100                               159_kpu_partai_peserta pemilu_verifikasi
#    160    100                                     160_juni_mal_dibuka juni_buka juni
#    161     99                                      161_berat badan_diet_tips_makanan
#    162     98                             162_jembatan_kaca_ambruk_jembatan tersebut
#    163     98                             163_bawang_bawang putih_harga bawang_putih
#    164     95                              164_jantung_stroke_serangan jantung_darah
#    165     94                           165_psikolog_depresi_mental_kesehatan mental
#    166     93                      166_ruu_perampasan aset_perampasan_ruu perampasan
#    167     93                                 167_instagram_komik_filter_tante ernie
#    168     93                           168_hutan_transmigrasi_kawasan hutan_iftitah
#    169     92                                      169_hoax_corona_hoax corona_virus
#    170     91                        170_penjara_divonis tahun_divonis_tahun penjara
#    171     91                                171_restoran_new normal_new_kuliner new
#    172     91                                   172_taksi_taksi online_online_driver
#    173     91                                             173_ular_sanca_piton_meter
#    174     90                                        174_ganja_dwi sasono_sasono_dwi
#    175     87                          175_sanitizer_hand sanitizer_hand_cuci tangan
#    176     86                                          176_netflix_serial_film_drama
#    177     86                                  177_pensiun_usia pensiun_usia_perwira
#    178     85                              178_sambo_geger_sumber archive_archive ph
#    179     85                         179_jadwal_april_april 2025_jadwal operasional
#    180     85                               180_tahanan_kabur_penjara_tahanan polsek
#    181     84                                     181_bank_kredit_rp triliun_triliun
#    182     82                          182_gubernur sulsel_gubernur_sulsel_riau jadi
#    183     82                                       183_sepeda_motor_rahmi_setiabudi
#    184     82                              184_wisatawan_destinasi_wisata_yogyakarta
#    185     81                                        185_uang palsu_palsu_sekar_uang
#    186     81                                     186_pertemuan_megawati_dasco_didit
#    187     80                                              187_comeback_nct_bts_soul
#    188     79                       188_australia_australia terbuka_beasiswa_terbuka
#    189     78                              189_drama_korea_drama korea_korea selatan
#    190     78                     190_pengunduran_pengunduran diri_diri_mengundurkan
#    191     78                                      191_the king_king_eternal_king of
#    192     78                                          192_banjir_air_hujan_terendam
#    193     77                                        193_pedagang_pasar_pembeli_kios
#    194     77                                        194_saya_donasi_perkenalkan_bpk
#    195     77                                           195_mobil_eco_racing_arteria
#    196     76                                     196_kapal china_kapal_natuna_china
#    197     76                                           197_lina_teddy_sule_eks sule
#    198     75                             198_corona_wisata_corona wisata_pariwisata
#    199     75                                    199_radioaktif_indah_limbah_tangsel
#    200     75                                 200_tahun baru_natal_pohon natal_pohon
#    201     74                                      201_ppn_pajak_ppn persen_kenaikan
#    202     74                                   202_china_zhang_ekonomi china_corona
#    203     74                             203_bunga_bunga acuan_taman bunga_acuan bi
#    204     74                                    204_abg_bocah_pembunuhan_slenderman
#    205     72                                     205_petani_jagung_panen_panen raya
#    206     72                                206_kota_pematangsiantar_wali kota_wali
#    207     72                  207_disinfektan_disemprot_disemprot disinfektan_cegah
#    208     71                    208_corona_corona pemerintah_pemerintah_soal corona
#    209     71                             209_dilarang_larangan mudik_mudik_larangan
#    210     70                                  210_perempuan_kartini_kesetaraan_laki
#    211     70                                       211_erupsi_gunung_letusan_semeru
#    212     70                        212_psbb_selama psbb_penumpang_angkut penumpang
#    213     70                                        213_coca cola_coca_cola_minuman
#    214     68                                        214_lumba_yuni shara_shara_yuni
#    215     68                  215_penculikan_penculikan anak_anak_pelaku penculikan
#    216     67                                   216_olahraga_atlet_latihan_kebugaran
#    217     66                       217_nihil_kasus baru_sebaran kasus_kasus positif
#    218     66                           218_hoax_jasa ekspedisi_ekspedisi_sebar hoax
#    219     66                                219_ambulans_etle_tilang_sopir ambulans
#    220     65                         220_reformasi_polri_reformasi polri_kepolisian
#    221     65                           221_facebook_akun facebook_login_pemblokiran
#    222     64                                       222_bus_bus akap_akap_beroperasi
#    223     63                                     223_pulau_world dream_sebaru_dream
#    224     63                                224_malam_lailatul qadar_qadar_lailatul
#    225     63                                         225_buku_novel_hari buku_rilis
#    226     63                                           226_desa_kuda_hantu_blt desa
#    227     63                             227_italia_lockdown_asmara abigail_abigail
#    228     62                                            228_000 000_000_anda_hadiah
#    229     61                                    229_energi_karbon_listrik_pertamina
#    230     61                               230_rumah_lebaran rumah_punya rumah_klau
#    231     61                            231_bank indonesia_bank_resminya bank_surat
#    232     60                                  232_tenaga medis_medis_perawat_tenaga
#    233     59                                   233_suhu tubuh_suhu_termometer_tubuh
#    234     59                                         234_yayasan_ira_kalibata_dapur
#    235     59                                 235_bank mega_diskon_allo_harga normal
#    236     59                                          236_gajah_rohil_riau_bengkulu
#    237     58                                   237_perampok_emas_toko emas_bersenpi
#    238     58                                   238_robot_humanoid_teknologi_robotik
#    239     58                                       239_princess_diamond_abk_wni abk
#    240     58                            240_rasisme_black lives_lives matter_matter
#    241     57                                         241_kamera_oppo_oppo reno_reno
#    242     57     242_karantina_karantina wilayah_jalani karantina_karantina mandiri
#    243     56                                  243_drone_bawah air_penampakan_munich
#    244     56                          244_bike_sepeda_bersepeda_mengikuti kompetisi
#    245     56                                       245_chef_masak_masak rumah_resep
#    246     55                                 246_ijazah_ugm_tpua_fakultas kehutanan
#    247     54                                 247_roy_ditangkap narkoba_kiki_narkoba
#    248     54                                        248_parasite_oscar_parasit_usus
#    249     54                              249_ditemukan tewas_tenggelam_tewas_bocah
#    250     53                                       250_turki_turkiye_ankara_antalya
#    251     53                  251_kesehatan_kesehatan gratis_skrining_cek kesehatan
#    252     53                            252_porno_syahrini_video porno_jadi bintang
#    253     53                                   253_nasi_rice_makan nasi_rice cooker
#    254     53                        254_halal_sertifikasi halal_produk halal_produk
#    255     53                                    255_puasa_kepuasan_keutamaan_survei
#    256     53                             256_imigrasi_keimigrasian_wna_izin tinggal
#    257     52                                       257_open house_house_istana_open
#    258     52                                     258_asuransi_jiwasraya_ojk_bos ojk
#    259     51                                            259_zoom_lens_pixel_imagine
#    260     51                                       260_paru_paru paru_batuk_di sini
#    261     51                              261_harley_harley davidson_davidson_quinn
#    262     51                          262_george floyd_floyd_george_kematian george
#    263     51                                       263_bully_penjual_viral_bullying
#    264     51                             264_pajak_pajak kendaraan_samsat_pemutihan
#    265     50                                               265_liar_cctv_depok_dede
#    266     50                                        266_paskah_gereja_katedral_misa
#    267     50                                             267_harga gas_gas_harga_us
#    268     50                                       268_lgbt_transgender_gay_kedubes
#    269     50                              269_china_hewan_transplantasi_hewan hidup
#    270     49                               270_rekomendasi_makan_resep_tempat makan
#    271     49                               271_kepuasan_puas_survei_kepuasan publik
#    272     49                                  272_salju_ski_sinterklas_musim dingin
#    273     49                                  273_penerbangan_boeing_china_maskapai
#    274     49                                     274_bom_teroris_yaqin_masjid nurul
#    275     49                                         275_uang_pecahan_rupiah_kertas
#    276     48                                       276_tikus_mouse_jalur tikus_asus
#    277     48                                  277_kota baru_ibu kota_ibu_pindah ibu
#    278     47                               278_toilet_mandi_kamar mandi_tisu toilet
#    279     47                                 279_kejuaraan_silat_atlet_pencak silat
#    280     47                          280_olimpiade_jadi tuan_hendra setiawan_cabor
#    281     47                                         281_vitamin_kulit_diet_makanan
#    282     47                                          282_komik_marvel_batman_joker
#    283     47                                   283_imigrasi_migran_iftitah_diaspora
#    284     46                                      284_terima kasih_kasih_terima_bye
#    285     46                          285_makanan_makanan gratis_inspiratif_netizen
#    286     46                                      286_unit_unit mobil_undian_gebyar
#    287     46                   287_wahyu setiawan_setiawan_komisioner kpu_kpu wahyu
#    288     46                       288_ventilator_pasien corona_pasien_pabrik mobil
#    289     45                               289_kualitas udara_udara_kualitas_polusi
#    290     45                                          290_eropa_copet_uni eropa_uni
#    291     45         291_proyek_infrastruktur_proyek infrastruktur_proyek strategis
#    292     45                                    292_demokrat_harris_jiwasraya_ketum
#    293     45                           293_sirkus_taman safari_safari_mantan pemain
#    294     45                                 294_ihsg_hijau_ihsg ditutup_zona hijau
#    295     45                   295_protokol kesehatan_protokol_kesehatan_new normal
#    296     44                 296_pengangguran_tingkat pengangguran_tembus_as tembus
#    297     44                                     297_pelaku_korban_polisi_diperkosa
#    298     44                       298_siber_serangan siber_serangan_keamanan siber
#    299     44                         299_pertahanan_pertahanan nasional_tni_sjafrie
#    300     44                                   300_yordania_qatar_abdullah ii_amman
#    301     44                     301_lockdown_corona_longgarkan lockdown_longgarkan
#    302     44                                                     302_62_0822_821_wa
#    303     43                               303_viral_viral pria_polisi_polisi turun
#    304     43                                  304_dharma_debat_kun_dharma pongrekun
#    305     43                         305_law cipta_cipta_cipta lapangan_omnibus law
#    306     43                                             306_jazz_festival_java_bni
#    307     43                              307_kota bogor_calon wali_urut_nomor urut
#    308     42                                    308_marquez_motogp_bagnaia_pembalap
#    309     42                                 309_guncang_baru saja_saja gempa_gempa
#    310     41                                                310_china_li_xi_jinping
#    311     41                                       311_kelapa_harga_ribu per_per kg
#    312     41                            312_terawan_obat_terawan agus_agus putranto
#    313     41                                  313_virus_virus corona_corona_makanan
#    314     40                                           314_marathon_lari_pelari_run
#    315     40                                  315_tni_panglima_panglima tni_sjafrie
#    316     40                            316_vietnam_https bit_bit ly_perang gerilya
#    317     39                             317_valentine_romantis_makan malam_rayakan
#    318     39                          318_india_kedubes_depan kedubes_jemaah tablig
#    319     39            319_revitalisasi monas_revitalisasi_monas_soal revitalisasi
#    320     39                                   320_sahur buka_buka rumah_sahur_buka
#    321     38                                   321_lucky_lucky hakim_ke jepang_izin
#    322     38                    322_distancing_social distancing_social_sosialisasi
#    323     38                                  323_bpjs_bpjs kesehatan_kesehatan_jkn
#    324     38                    324_pembatasan sosial_pembatasan_skala besar_sanksi
#    325     38                                      325_titi_rumah sakit_dokter_sakit
#    326     38                                          326_ikan_seafood_sarden_resep
#    327     37                                           327_gitar_lagu_gitaris_lirik
#    328     37                                         328_inflasi_andil_fed_terendah
#    329     37                                  329_mcgregor_conor mcgregor_conor_ufc
#    330     37                                          330_sayur_sayuran_resep_salad
#    331     37                                    331_papua_kapolda papua_kapolda_pon
#    332     37                                    332_impor_tekstil_kuota impor_kuota
#    333     37                                          333_baim_baim wong_wong_sukma
#    334     37                                   334_telkomsel_internet_telkom_trafik
#    335     36                                         335_emas_harga emas_gram_antam
#    336     36                                           336_rp juta_mulai rp_juta_rp
#    337     36                               337_kabel_menjuntai_semrawut_kabel kabel
#    338     36                                        338_virtual_luna maya_maya_luna
#    339     36                                339_diabetes_kadar gula_gula darah_gula
#    340     36                                      340_pajak_pbb_keringanan_olahraga
#    341     36                                   341_corona_pabrik mobil_pabrik_setop
#    342     35                                       342_spider_spider man_man_marvel
#    343     35                                              343_sigit_arus_rest_mudik
#    344     35                                344_vitalia_sesha_vitalia sesha_narkoba
#    345     35                          345_kemiskinan_batang_angka kemiskinan_miskin
#    346     35                                 346_pertamina_direksi_dipangkas_kilang
#    347     35                                     347_china_bangganya_build up_build
#    348     35                              348_internet_online_belajar_belajar rumah
#    349     35                  349_podcast_podcast penonton_penonton bayaran_spotify
#    350     35                             350_plastik_kantong plastik_kantong_larang
#    351     35                                          351_tol_jalan tol_struk_jalan
#    352     34                                       352_netizen_liza aditya_liza_psk
#    353     34                                           353_ijazah_ugm_disertasi_roy
#    354     34                                       354_marcell_darwin_nabila_faisal
#    355     34                                   355_2024_pilpres 2024_ganjar_di 2024
#    356     34                                          356_laptop_prosesor_amd_intel
#    357     33                                      357_hilal_syawal_1446_syawal 1446
#    358     33                358_banjir_akibat banjir_orang tewas_banjir jabodetabek
#    359     33                        359_rohingya_pengungsi_pengungsi rohingya_unhcr
#    360     33                                         360_ferrari_ford_ngebul_hermes
#    361     33                               361_pooroe_karen pooroe_karen_anak karen
#    362     33                                        362_tyson_mike tyson_mike_tinju
#    363     33                                      363_kongres pan_kongres_pan_asman
#    364     33                              364_bendera_one piece_piece_bendera merah
#    365     33                                 365_wisata_tempat wisata_ditutup_tutup
#    366     33                            366_lockdown_zona_melawi_counter penjelasan
#    367     32                                         367_burger_kekinian_roti_selai
#    368     32                                     368_darah_donor_plasma_donor darah
#    369     32                           369_phk_kena phk_dirumahkan_ratusan karyawan
#    370     32                                         370_orang tua_anak_tua_depresi
#    371     32                                        371_shin_shin tae_tae yong_yong
#    372     32                                 372_tutup_pasar tanah_toko_tanah abang
#    373     32                                           373_tol_2025_tarif tol_tarif
#    374     32                                      374_suara_buka suara_heli_heli mi
#    375     32                                  375_museum_macan_arisan_museum museum
#    376     32                                          376_kg_elpiji kg_rp kg_elpiji
#    377     32                                 377_australia_pulau pasir_tempur_video
#    378     32                                    378_grammy awards_grammy_awards_bts
#    379     32                                  379_prostitusi_abg_kalibata_apartemen
#    380     32                     380_ragunan_pengunjung_margasatwa_taman margasatwa
#    381     31                              381_perkawinan_perceraian_poligami_pergub
#    382     31                                      382_perpustakaan_buku_ukuran_word
#    383     31        383_pernyataan lengkap_pemerintah soal_kasus positif_soal kasus
#    384     31                            384_tpks_seksual_ruu tpks_kekerasan seksual
#    385     31                              385_jenazah_pdp corona_jenazah pasien_pdp
#    386     31                                   386_meninggal_duka_abdul ghani_ghani
#    387     31                            387_sumpah pemuda_sumpah_pemuda_hari sumpah
#    388     31                                 388_cinta_kisah cinta_love_akhir kisah
#    389     31                                 389_taman_langsat_24 jam_taman langsat
#    390     31                          390_terkaya_orang terkaya_terkaya dunia_dunia
#    391     30                                      391_minum_minum air_dehidrasi_air
#    392     30                                         392_capim_dubes_fit and_pansel
#    393     30                                  393_maia_estianty_maia estianty_dhani
#    394     30                    394_sejarah_penulisan_ulang sejarah_penulisan ulang
#    395     30                                        395_tv_radio_televisi_streaming
#    396     30                                          396_buyback_saham_emiten_rups
#    397     30                                  397_sri mulyani_mulyani_sri_dana desa
#    398     29                         398_payudara_begal payudara_begal_korban begal
#    399     29                                  399_minyak_minyak goreng_goreng_harga
#    400     29                                 400_wisma atlet_wisma_atlet_rs darurat
#    401     29                                       401_korut_korea_korea utara_jong
#    402     29                                       402_pandemi_covid_omicron_varian
#    403     29                                403_patroli_kamtibmas_metro_polda metro
#    404     29                                         404_yoon_pemakzulan_korsel_suk
#    405     29                                        405_kobe_bryant_kobe bryant_nba
#    406     29                                406_dinosaurus_fosil_juta tahun_spesies
#    407     29                               407_pizza_film parasite_voucher_parasite
#    408     29                408_disabilitas_penyandang disabilitas_penyandang_fajri
#    409     28                                  409_muhyiddin_mahathir_anwar_malaysia
#    410     28                                             410_sampah_tps_dlhk_supian
#    411     28                                         411_arfan_lebam_sw_kebon jeruk
#    412     28                               412_orator_kritik_orator aksi_dpr kritik
#    413     28                                       413_dana haji_haji_nganggur_dana
#    414     28                                            414_superman_film_marvel_dc
#    415     28                                 415_vitamin_tahan tubuh_daya tahan_sea
#    416     28                                        416_mata uang_rp16_dolar_rupiah
#    417     28                                        417_lina_autopsi_sule_diautopsi
#    418     28                                    418_pisang_makan pisang_dempet_daun
#    419     28                                    419_tenaga medis_medis_hotel_tenaga
#    420     28                                        420_pdp odp_odp_positif pdp_pdp
#    421     28                                        421_obesitas_truk_lewat tol_tol
#    422     28                                      422_from home_work from_work_home
#    423     28                         423_ditemukan tewas_ditemukan_mayat pria_mayat
#    424     27                                      424_senyum_joy_bahagia_wni pulang
#    425     27                   425_kecelakaan_kecelakaan lalu_angka kecelakaan_arus
#    426     27                             426_tiket_tiket kereta_refund tiket_refund
#    427     27                                      427_eropa_uni eropa_cepa_ieu cepa
#    428     27                                428_curi_motor_pencuri_ditangkap polisi
#    429     27                                          429_opm_tpnpb_papua_tpnpb opm
#    430     27                                  430_rambut_potong rambut_cukur_potong
#    431     27                            431_sampah_birmingham_tumpukan sampah_mogok
#    432     27                                     432_gigi_dentuman_dokter gigi_odol
#    433     27                      433_australia_pulau pasir_protection_di australia
#    434     27                                434_mengejutkan_rezim ini_rezim_terkini
#    435     27                                        435_perang_world war_war_jateng
#    436     27                                   436_massa_massa aksi_aksi_gedung dpr
#    437     26                       437_aplikasi_pegadaian_pedulilindungi_verifikasi
#    438     26                                        438_dana desa_blt dana_blt_desa
#    439     26                          439_iklim_pakistan_perubahan iklim_iklim yang
#    440     26                                   440_gigi_pasta gigi_pasta_sakit gigi
#    441     26                                         441_air terjun_terjun_air_sewu
#    442     26                                  442_radiasi_cesium_radioaktif_cikande
#    443     26                        443_rehabilitasi_direhabilitasi_rsko_dwi sasono
#    444     26                                   444_pohon_tanam_monas_pohon beringin
#    445     26                                             445_iran_nuklir_as_teheran
#    446     26                           446_lobster_benih lobster_benih_ekspor benih
#    447     26                                       447_ekspor_impor_miliar turun_us
#    448     25                                        448_fans_kang daniel_duh_eminem
#    449     25                                 449_hacker_malware_situs dpr_dimatikan
#    450     25                                      450_mata_penglihatan_lensa_dokter
#    451     25                                     451_nyamuk_frekuensi_airpods_india
#    452     25                                          452_korea_idol_makanan_kimchi
#    453     25                               453_amunisi_pemusnahan_ledakan_detonator
#    454     25                            454_hotma_sitompul_hotma sitompul_pengacara
#    455     25                                    455_enfield_royal enfield_bjb_royal
#    456     25                                          456_bank dki_bank_dki_nasabah
#    457     25                               457_psu_suara ulang_tps_pemungutan suara
#    458     25     458_lowongan_dinas kesehatan_lowongan pekerjaan_informasi lowongan
#    459     25                                 459_styles_harry_langsing_transformasi
#    460     25                                      460_harga bbm_bbm_bbm turun_turun
#    461     24                                      461_urine_tes urine_tes_hasil tes
#    462     24                                      462_tni_upacara_hut tni_alutsista
#    463     24                                        463_netflix_pajak_cs_kena pajak
#    464     24                                   464_hewan_anjing_virus_herd immunity
#    465     24 465_kecelakaan_kecelakaan mobil_kejadian kecelakaan_kecelakaan terjadi
#    466     24                                   466_susu_peternak_peternak sapi_sapi
#    467     24                   467_darurat_darurat bencana_bencana_bencana nasional
#    468     24                                  468_kripto_rekening_aset kripto_ppatk
#    469     24                        469_bensin_bensin eceran_isi bensin_rolls royce
#    470     24                                      470_mudik_harga_bahan pokok_sigit
#    471     24                              471_evakuasi_wni wuhan_evakuasi wni_wuhan
#    472     24                                   472_ashraf_bcl_diego hills_san diego
#    473     24                   473_narkoba_kasus narkoba_terkait narkoba_pakusadewo
#    474     23                            474_turis china_turis_china_kunjungan turis
#    475     23                                     475_kingdom_musim kedua_musim_cast
#    476     23                                           476_jenazah_mayat_covid_mama
#    477     23                                477_pulau galang_galang_rs corona_pulau
#    478     23                   478_saksi_jiwasraya_kejagung periksa_kasus jiwasraya
#    479     23                                          479_eks isis_wni eks_isis_wni
#    480     23                               480_titiek puspa_puspa_titiek_kebudayaan
#    481     23                                  481_mahasiswa_aksi_massa_depan gedung
#    482     23                                     482_mineral_bara_batu bara_tambang
#    483     23                          483_chrisye_istri_mantan istri_istri mendiang
#    484     23                              484_potong gaji_gaji_potong_gaji karyawan
#    485     23                                           485_bocah_trauma_ngaku_robek
#    486     23                               486_gen halilintar_gen_halilintar_mutasi
#    487     23                                    487_agama_beragama_pendakwah_miftah
#    488     22                                       488_sperma_pria_punya anak_donor
#    489     22                                     489_donasi_salurkan_indihome_covid
#    490     22                         490_kelayakan_uji kelayakan_and proper_fit and
#    491     22                     491_captain_captain america_america_captain marvel
#    492     22                                  492_klorokuin_obat corona_obat_corona
#    493     22                            493_mafia_alat kesehatan_migas_begini modus
#    494     22                            494_ibu kota_ibu_pemindahan ibu_kota negara
#    495     22                                  495_taliban_afghanistan_pakistan_mati
#    496     22                            496_lapas_warga binaan_pemasyarakatan_rutan
#    497     22                                       497_digital_anda_anda bisa_jejak
#    498     22                                  498_psu_tps_kabupaten_pelaksanaan psu
#    499     22                                 499_bunuh diri_bunuh_diri_lucinta luna
#    500     21                                  500_dubes_washington dc_dc_washington
#    501     21                                      501_durian_enak_legit_manis legit
#    502     21                           502_imunitas_imunitas tubuh_tingkatkan_tubuh
#    503     21                                       503_saya_kita_pco_jubir presiden
#    504     21                                   504_kamboja_soleh_karding_di kamboja
#    505     21                 505_menteri_jiwasraya_menteri yasonna_pansus jiwasraya
#    506     21                                             506_armuji_diana_ijazah_ud
#    507     21                                    507_abadi_megawati_lord_soal natuna
#    508     21                                        508_kota baru_ahok_ibu kota_ibu
#    509     21                          509_phk_phk karyawan_indosat_karyawan indosat
#    510     20                                 510_bos_bos ojk_kata bos_bos pertamina
#    511     20                                     511_baterai_ponsel_charging_galaxy
#    512     20                                     512_trump_chicago_presiden as_musk
#    513     20                                      513_wni_judha_evakuasi_dievakuasi
#    514     20                      514_bencana_terdampak_tagana_masyarakat terdampak
#    515     20                                     515_polusi_polusi udara_udara_eror
#    516     20                             516_singapura_anwar_malaysia_lawrence wong
#    517     20                                           517_ginjal_organ_kenya_donor
#    518     20                                                    518_ly_pin_bit_anda
#    519     20                                      519_hijab_berhijab_unggah_goeslaw
#    520     20                 520_peserta_ditjen_dilaksanakan pada_akan dilaksanakan
#    521     20                                    521_ninja_kawasaki_silinder_raungan
#    522     20                                522_ria ricis_ricis_rusak_tol palembang
#    523     20                                       523_bill gates_bill_gates_corona
#    524     20      524_ombudsman_maladministrasi_tim bentukan_dugaan maladministrasi
#    525     20                                       525_buka puasa_jadwal_buka_puasa
#    526     19                    526_sirkuit_sirkuit formula_formula_formula jakarta
#    527     19                                527_ormas_tambang_premanisme_raja ampat
#    528     19                                          528_amazon_gudang_anda_rekrut
#    529     19                             529_bpjs_bpjs kesehatan_peserta bpjs_kelas
#    530     19                              530_quick count_count_quick_cagub cawagub
#    531     19                             531_mangrove_ekosistem_gambut_rehabilitasi
#    532     19                                  532_tumbang_pohon_pohon tumbang_hujan
#    533     19                                       533_jual_syahputra_olga_mewahnya
#    534     19                                          534_manga_one piece_piece_one
#    535     19                           535_panda_nababan_berbohong_politikus golkar
#    536     19                   536_manipulasi_rekomendasi_dugaan manipulasi_bawahan
#    537     19                           537_kopdes_koperasi_kopdes merah_merah putih
#    538     19           538_sarah salsabila_keperawanan_salsabila_lelang keperawanan
#    539     19                               539_prakiraan_cuaca_prakiraan cuaca_bmkg
#    540     19                                  540_alzheimer_caregiver_merawat_nadia
#    541     19                                    541_gereja_sri lanka_lanka_serangan
#    542     19                                        542_beruang_slovakia_madu_kurus
#    543     19                                    543_bayi_kloset_bayi tersebut_mayat
#    544     19                   544_diperingati_tanggal_peringatan_tanggal september
#    545     19                                      545_china_difoto_trenggiling_cina
#    546     18                                                546_dance_pole_tari_cha
#    547     18                                   547_batman_penguin_the batman_robert
#    548     18                                   548_argentina_messi_gol_pertandingan
#    549     18                                    549_galaxy_galaksi_galaxy fold_lite
#    550     18                                              550_jpo_bandan_besi_mogot
#    551     18                                           551_bendera_unhas_arit_lutfi
#    552     18                             552_kamera_ponsel_kamera ponsel_pro ponsel
#    553     18                                             553_huawei_pro_mate_google
#    554     18                                     554_tautan_ke laman_laman_lowongan
#    555     18                                   555_camping_tenda_camp_dokumen amdal
#    556     18              556_kolesterol_kolesterol tinggi_kadar kolesterol_usia an
#    557     18                          557_pelabuhan_dermaga_bakauheni_pemudik motor
#    558     18                                           558_on you_crash_landing_you
#    559     18                                    559_rina nose_nose_latuconsina_rina
# ...
#       592     592_tipe_tulang_arthritis_sendi     5                 penyakit     0.044762
#       592     592_tipe_tulang_arthritis_sendi     6                penderita     0.042137
#       592     592_tipe_tulang_arthritis_sendi     7             dokter tirta     0.027010
#       592     592_tipe_tulang_arthritis_sendi     8                   gejala     0.023135
#       592     592_tipe_tulang_arthritis_sendi     9                    tirta     0.020305
#       592     592_tipe_tulang_arthritis_sendi    10                   dokter     0.019860
#       593 593_hotman paris_hotman_paris_sinar     1             hotman paris     0.444554
#       593 593_hotman paris_hotman_paris_sinar     2                   hotman     0.422646
#       593 593_hotman paris_hotman_paris_sinar     3                    paris     0.329014
#       593 593_hotman paris_hotman_paris_sinar     4                 sinarmas     0.074650
#       593 593_hotman paris_hotman_paris_sinar     5                     gara     0.070860
#       593 593_hotman paris_hotman_paris_sinar     6               reksa dana     0.068866
#       593 593_hotman paris_hotman_paris_sinar     7                    reksa     0.067962
#       593 593_hotman paris_hotman_paris_sinar     8                    bella     0.060341
#       593 593_hotman paris_hotman_paris_sinar     9              sandra dewi     0.058749
#       593 593_hotman paris_hotman_paris_sinar    10                   sandra     0.055231
#       594         594_tips_trick_wfh_kepayang     1                     tips     0.536053
#       594         594_tips_trick_wfh_kepayang     2                    trick     0.142330
#       594         594_tips_trick_wfh_kepayang     3                      wfh     0.100938
#       594         594_tips_trick_wfh_kepayang     4                 kepayang     0.083042
#       594         594_tips_trick_wfh_kepayang     5               tips mudah     0.083042
#       594         594_tips_trick_wfh_kepayang     6                tips tips     0.083042
#       594         594_tips_trick_wfh_kepayang     7               ikuti tips     0.081272
#       594         594_tips_trick_wfh_kepayang     8                tips jaga     0.079776
#       594         594_tips_trick_wfh_kepayang     9                baca dulu     0.079776
#       594         594_tips_trick_wfh_kepayang    10                   motret     0.078480
#       595          595_dj_gempi_gading_marten     1                       dj     0.498706
#       595          595_dj_gempi_gading_marten     2                    gempi     0.156697
#       595          595_dj_gempi_gading_marten     3                   gading     0.100755
#       595          595_dj_gempi_gading_marten     4                   marten     0.100302
#       595          595_dj_gempi_gading_marten     5                     mama     0.077680
#       595          595_dj_gempi_gading_marten     6         giorgino abraham     0.076776
#       595          595_dj_gempi_gading_marten     7                 giorgino     0.075414
#       595          595_dj_gempi_gading_marten     8                  passion     0.070079
#       595          595_dj_gempi_gading_marten     9            gading marten     0.069351
#       595          595_dj_gempi_gading_marten    10                    ngaku     0.066398
#       596   596_mawar de_de jongh_jongh_mawar     1                 mawar de     0.472978
#       596   596_mawar de_de jongh_jongh_mawar     2                 de jongh     0.465507
#       596   596_mawar de_de jongh_jongh_mawar     3                    jongh     0.465507
#       596   596_mawar de_de jongh_jongh_mawar     4                    mawar     0.349301
#       596   596_mawar de_de jongh_jongh_mawar     5                       de     0.270387
#       596   596_mawar de_de jongh_jongh_mawar     6                     rose     0.114896
#       596   596_mawar de_de jongh_jongh_mawar     7                sayangnya     0.094531
#       596   596_mawar de_de jongh_jongh_mawar     8               patah hati     0.090925
#       596   596_mawar de_de jongh_jongh_mawar     9                     ruby     0.090143
#       596   596_mawar de_de jongh_jongh_mawar    10                   sayang     0.088156
#       597 597_masuk jakarta_keluar masuk_izin     1            masuk jakarta     0.221667
#       597 597_masuk jakarta_keluar masuk_izin     2             keluar masuk     0.170412
#       597 597_masuk jakarta_keluar masuk_izin     3              izin keluar     0.111635
#       597 597_masuk jakarta_keluar masuk_izin     4                   keluar     0.095563
#       597 597_masuk jakarta_keluar masuk_izin     5               surat izin     0.084687
#       597 597_masuk jakarta_keluar masuk_izin     6            jakarta mulai     0.061903
#       597 597_masuk jakarta_keluar masuk_izin     7                     izin     0.061213
#       597 597_masuk jakarta_keluar masuk_izin     8              minta warga     0.060940
#       597 597_masuk jakarta_keluar masuk_izin     9              begini cara     0.058472
#       597 597_masuk jakarta_keluar masuk_izin    10                keluarkan     0.054526
#       598 598_petani_poso_tewas_ditemukan tew     1                   petani     0.288672
#       598 598_petani_poso_tewas_ditemukan tew     2                     poso     0.239250
#       598 598_petani_poso_tewas_ditemukan tew     3                    tewas     0.180557
#       598 598_petani_poso_tewas_ditemukan tew     4          ditemukan tewas     0.139778
#       598 598_petani_poso_tewas_ditemukan tew     5            diduga korban     0.123096
#       598 598_petani_poso_tewas_ditemukan tew     6                    barru     0.095132
#       598 598_petani_poso_tewas_ditemukan tew     7             korban salah     0.084854
#       598 598_petani_poso_tewas_ditemukan tew     8                    kebun     0.080532
#       598 598_petani_poso_tewas_ditemukan tew     9                ditemukan     0.073806
#       598 598_petani_poso_tewas_ditemukan tew    10                  diculik     0.069439
#       599       599_kereta_kereta api_kai_api     1                   kereta     0.061296
#       599       599_kereta_kereta api_kai_api     2               kereta api     0.041720
#       599       599_kereta_kereta api_kai_api     3                      kai     0.037421
#       599       599_kereta_kereta api_kai_api     4                      api     0.028942
#       599       599_kereta_kereta api_kai_api     5                   porter     0.023291
#       599       599_kereta_kereta api_kai_api     6                    tiket     0.022208
#       599       599_kereta_kereta api_kai_api     7                penumpang     0.018602
#       599       599_kereta_kereta api_kai_api     8                  stasiun     0.015832
#       599       599_kereta_kereta api_kai_api     9                   access     0.015797
#       599       599_kereta_kereta api_kai_api    10                       ka     0.015175
#       600    600_jalan_lalu lintas_tol_lintas     1                    jalan     0.021214
#       600    600_jalan_lalu lintas_tol_lintas     2              lalu lintas     0.017834
#       600    600_jalan_lalu lintas_tol_lintas     3                      tol     0.017763
#       600    600_jalan_lalu lintas_tol_lintas     4                   lintas     0.015784
#       600    600_jalan_lalu lintas_tol_lintas     5                jalan tol     0.013278
#       600    600_jalan_lalu lintas_tol_lintas     6                   parkir     0.013235
#       600    600_jalan_lalu lintas_tol_lintas     7                     ruas     0.013188
#       600    600_jalan_lalu lintas_tol_lintas     8               ruas jalan     0.012486
#       600    600_jalan_lalu lintas_tol_lintas     9               yogyakarta     0.012357
#       600    600_jalan_lalu lintas_tol_lintas    10          kota yogyakarta     0.011778
#       601 601_sembuh_pasien_positif covid_pas     1                   sembuh     0.265652
#       601 601_sembuh_pasien_positif covid_pas     2                   pasien     0.197280
#       601 601_sembuh_pasien_positif covid_pas     3            positif covid     0.194787
#       601 601_sembuh_pasien_positif covid_pas     4           pasien positif     0.175729
#       601 601_sembuh_pasien_positif covid_pas     5               kabar baik     0.152945
#       601 601_sembuh_pasien_positif covid_pas     6             sembuh covid     0.151118
#       601 601_sembuh_pasien_positif covid_pas     7               covid kota     0.151118
#       601 601_sembuh_pasien_positif covid_pas     8                    covid     0.122258
#       601 601_sembuh_pasien_positif covid_pas     9            kota semarang     0.116126
#       601 601_sembuh_pasien_positif covid_pas    10                  positif     0.100862
#       602 602_houthi_serangan_yaman_laut mera     1                   houthi     0.090108
#       602 602_houthi_serangan_yaman_laut mera     2                 serangan     0.040094
#       602 602_houthi_serangan_yaman_laut mera     3                    yaman     0.034374
#       602 602_houthi_serangan_yaman_laut mera     4               laut merah     0.022096
#       602 602_houthi_serangan_yaman_laut mera     5                       as     0.021320
#       602 602_houthi_serangan_yaman_laut mera     6           serangan udara     0.020092
#       602 602_houthi_serangan_yaman_laut mera     7               militer as     0.016379
#       602 602_houthi_serangan_yaman_laut mera     8                 terhadap     0.016125
#       602 602_houthi_serangan_yaman_laut mera     9                    kapal     0.015321
#       602 602_houthi_serangan_yaman_laut mera    10                  di laut     0.014195
#       603 603_ramadan_kita_memaafkan_bulan ra     1                  ramadan     0.052943
#       603 603_ramadan_kita_memaafkan_bulan ra     2                     kita     0.019233
#       603 603_ramadan_kita_memaafkan_bulan ra     3                memaafkan     0.019187
#       603 603_ramadan_kita_memaafkan_bulan ra     4            bulan ramadan     0.018942
#       603 603_ramadan_kita_memaafkan_bulan ra     5                    gadai     0.018291
#       603 603_ramadan_kita_memaafkan_bulan ra     6                 asuransi     0.012979
#       603 603_ramadan_kita_memaafkan_bulan ra     7                     hati     0.012405
#       603 603_ramadan_kita_memaafkan_bulan ra     8                     tapi     0.011266
#       603 603_ramadan_kita_memaafkan_bulan ra     9                  lebaran     0.010939
#       603 603_ramadan_kita_memaafkan_bulan ra    10                kemuliaan     0.010305
#       604 604_cfd_car free_bebas kendaraan_ca     1                      cfd     0.058040
#       604 604_cfd_car free_bebas kendaraan_ca     2                 car free     0.041711
#       604 604_cfd_car free_bebas kendaraan_ca     3          bebas kendaraan     0.040287
#       604 604_cfd_car free_bebas kendaraan_ca     4                      car     0.038339
#       604 604_cfd_car free_bebas kendaraan_ca     5               hari bebas     0.035971
#       604 604_cfd_car free_bebas kendaraan_ca     6                     free     0.035751
#       604 604_cfd_car free_bebas kendaraan_ca     7                 free day     0.035354
#       604 604_cfd_car free_bebas kendaraan_ca     8       kendaraan bermotor     0.028902
#       604 604_cfd_car free_bebas kendaraan_ca     9                 bermotor     0.028298
#       604 604_cfd_car free_bebas kendaraan_ca    10                      day     0.026663
#       605 605_hadiahnya_turnamen_mobile_pubg      1                hadiahnya     0.194183
#       605 605_hadiahnya_turnamen_mobile_pubg      2                 turnamen     0.185668
#       605 605_hadiahnya_turnamen_mobile_pubg      3                   mobile     0.171735
#       605 605_hadiahnya_turnamen_mobile_pubg      4              pubg mobile     0.157072
#       605 605_hadiahnya_turnamen_mobile_pubg      5           mobile legends     0.155848
#       605 605_hadiahnya_turnamen_mobile_pubg      6                  legends     0.152547
#       605 605_hadiahnya_turnamen_mobile_pubg      7                     pubg     0.145637
#       605 605_hadiahnya_turnamen_mobile_pubg      8                   league     0.124947
#       605 605_hadiahnya_turnamen_mobile_pubg      9                   esport     0.103127
#       605 605_hadiahnya_turnamen_mobile_pubg     10                hadiah rp     0.099210
#       606 606_bripda_uang palsu_sekar_rp juta     1                   bripda     0.016517
#       606 606_bripda_uang palsu_sekar_rp juta     2               uang palsu     0.013696
#       606 606_bripda_uang palsu_sekar_rp juta     3                    sekar     0.013111
#       606 606_bripda_uang palsu_sekar_rp juta     4                  rp juta     0.011320
#       606 606_bripda_uang palsu_sekar_rp juta     5                 malaysia     0.010991
#       606 606_bripda_uang palsu_sekar_rp juta     6              polda metro     0.010878
#       606 606_bripda_uang palsu_sekar_rp juta     7               metro jaya     0.010772
#       606 606_bripda_uang palsu_sekar_rp juta     8             investasi rp     0.010556
#       606 606_bripda_uang palsu_sekar_rp juta     9                     uang     0.010543
#       606 606_bripda_uang palsu_sekar_rp juta    10                    metro     0.010437
#       607          607_snbt_utbk_seleksi_snbp     1                     snbt     0.035157
#       607          607_snbt_utbk_seleksi_snbp     2                     utbk     0.029550
#       607          607_snbt_utbk_seleksi_snbp     3                  seleksi     0.029155
#       607          607_snbt_utbk_seleksi_snbp     4                     snbp     0.029066
#       607          607_snbt_utbk_seleksi_snbp     5                    snpmb     0.024269
#       607          607_snbt_utbk_seleksi_snbp     6         seleksi nasional     0.019345
#       607          607_snbt_utbk_seleksi_snbp     7                  peserta     0.018867
#       607          607_snbt_utbk_seleksi_snbp     8                      ptn     0.018447
#       607          607_snbt_utbk_seleksi_snbp     9                utbk snbt     0.017877
#       607          607_snbt_utbk_seleksi_snbp    10          calon mahasiswa     0.016636
#       608 608_demokrasi_ahy_mahfud_warga nega     1                demokrasi     0.034857
#       608 608_demokrasi_ahy_mahfud_warga nega     2                      ahy     0.009333
#       608 608_demokrasi_ahy_mahfud_warga nega     3                   mahfud     0.008882
#       608 608_demokrasi_ahy_mahfud_warga nega     4             warga negara     0.008133
#       608 608_demokrasi_ahy_mahfud_warga nega     5                   rakyat     0.007757
#       608 608_demokrasi_ahy_mahfud_warga nega     6            generasi muda     0.007542
#       608 608_demokrasi_ahy_mahfud_warga nega     7                kebebasan     0.007440
#       608 608_demokrasi_ahy_mahfud_warga nega     8                  memilih     0.007262
#       608 608_demokrasi_ahy_mahfud_warga nega     9                  politik     0.007217
#       608 608_demokrasi_ahy_mahfud_warga nega    10               kitab suci     0.006520
#       609   609_bunga_juta_bunga bank_bank rp     1                    bunga     0.109945
#       609   609_bunga_juta_bunga bank_bank rp     2                     juta     0.107214
#       609   609_bunga_juta_bunga bank_bank rp     3               bunga bank     0.102518
#       609   609_bunga_juta_bunga bank_bank rp     4                  bank rp     0.097699
#       609   609_bunga_juta_bunga bank_bank rp     5                   sarita     0.093679
#       609   609_bunga_juta_bunga bank_bank rp     6                   pinjam     0.071591
#       609   609_bunga_juta_bunga bank_bank rp     7              juta rupiah     0.067729
#       609   609_bunga_juta_bunga bank_bank rp     8                  rp juta     0.065128
#       609   609_bunga_juta_bunga bank_bank rp     9                pegadaian     0.061416
#       609   609_bunga_juta_bunga bank_bank rp    10            pemudik nekat     0.057461
#
# Hasil c-TF-IDF disimpan: evaluasi_ctfidf_topik.csv
# Heatmap c-TF-IDF disimpan: ctfidf_heatmap.png  (annot=off, matriks terlalu besar)

# %%
# ================================================================
# SEL 26 -- Simpan Artefak BERTopic ke /content & Zip
# ================================================================
if AKTIFKAN_BERTOPIC and model_topik is not None:
    os.makedirs(DIR_OUTPUT_BERTOPIC, exist_ok=True)
    try:
        model_topik.save(DIR_OUTPUT_BERTOPIC, serialization="safetensors")
        print(f"BERTopic disimpan (safetensors) ke: {DIR_OUTPUT_BERTOPIC}")
    except TypeError:
        model_topik.save(DIR_OUTPUT_BERTOPIC)
        print(f"BERTopic disimpan (default) ke: {DIR_OUTPUT_BERTOPIC}")
    path_zip = shutil.make_archive(DIR_OUTPUT_BERTOPIC, "zip", DIR_OUTPUT_BERTOPIC)
    print(f"Zip: {path_zip}  ({os.path.getsize(path_zip)/1e6:.1f} MB)")
else:
    print("Model BERTopic belum tersedia; proses simpan dilewati.")
# Out:
# BERTopic disimpan (safetensors) ke: /content/bertopic_model_v3
# Zip: /content/bertopic_model_v3.zip  (1.1 MB)

# %%
# ================================================================
# SEL 27 -- Demo Inferensi Topik per Paragraf (BERTopic)
# ================================================================
# [FIX B1]   Regex DIPERBAIKI: r"(?:\r?\n){2,}"
#             Bug asli: double-escaped \r\n tidak pernah match
#             karena dalam raw string \r adalah dua karakter literal.
# [FIX LR-4] Re-init embedder karena sudah dihapus di SEL 24.
# ================================================================
import re as _re

# [FIX B1] Regex yang benar -- single backslash untuk \r dan \n
REGEX_PARAGRAF_DEMO = _re.compile("(?:\r?\n){2,}")


def pisahkan_paragraf_demo(teks: str) -> List[str]:
    mentah = str(teks).strip()
    if not mentah: return []
    bagian = [p.strip() for p in REGEX_PARAGRAF_DEMO.split(mentah) if p.strip()]
    return bagian if bagian else [mentah]


def label_dari_id_topik(obj_model, t_id: int) -> str:
    info  = obj_model.get_topic_info()
    baris = info[info["Topic"] == t_id]
    if len(baris) > 0 and "Name" in baris.columns:
        return str(baris.iloc[0]["Name"])
    kata = obj_model.get_topic(t_id)
    return " / ".join([w for w,_ in kata[:3]]) if kata else "topik_tidak_dikenal"


def skor_dari_prob(pb, t_id: int):
    if pb is None: return None
    if isinstance(pb, np.ndarray):
        if pb.ndim == 0: return float(pb)
        if 0 <= t_id < len(pb): return float(pb[t_id])
        return float(np.max(pb)) if pb.size > 0 else None
    return None


CONTOH_TOPIK = (
    "\nBeredar tautan bantuan tunai yang meminta OTP pengguna.\n\n"
    "Kementerian mengklarifikasi bahwa tautan tersebut palsu "
    "dan meminta warga cek kanal resmi.\n\n"
    "Pengguna lain melaporkan modus serupa berujung pada pencurian akun.\n"
)

if AKTIFKAN_BERTOPIC and model_topik is not None:
    daftar_par = pisahkan_paragraf_demo(CONTOH_TOPIK)
    print(f"Jumlah paragraf: {len(daftar_par)}  [FIX B1: regex diperbaiki]")

    if daftar_par:
        # [FIX LR-4] Re-init embedder karena sudah dihapus di SEL 24
        _emb_inf = SentenceTransformer(
            MODEL_EMBEDDING_BERTOPIC,
            device="cuda" if torch.cuda.is_available() else "cpu",
        )
        emb_par = _emb_inf.encode(
            daftar_par, batch_size=UKURAN_BATCH_EMBED,
            show_progress_bar=False, convert_to_numpy=True, normalize_embeddings=True,
        )
        del _emb_inf; gc.collect()
        if torch.cuda.is_available(): torch.cuda.empty_cache()

        id_par, prob_par = model_topik.transform(daftar_par, embeddings=emb_par)

        print("\nHasil topik per paragraf:")
        for idx, (teks_p, t_id) in enumerate(zip(daftar_par, id_par)):
            skor  = skor_dari_prob(prob_par[idx] if prob_par is not None else None, t_id)
            lbl   = label_dari_id_topik(model_topik, t_id)
            print(f"  Paragraf {idx}: Topik {t_id} | {lbl} | "
                  f"skor={f'{skor:.4f}' if skor is not None else 'N/A'}")
            print(f"  Teks: {teks_p}\n")
else:
    print("Demo BERTopic dilewati karena model belum di-fit.")
# Out:
# Jumlah paragraf: 3  [FIX B1: regex diperbaiki]
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 2026-04-10 12:49:37,229 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2026-04-10 12:49:58,888 - BERTopic - Dimensionality - Completed ✓
# 2026-04-10 12:49:58,889 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2026-04-10 12:49:58,894 - BERTopic - Cluster - Completed ✓
# Hasil topik per paragraf:
#   Paragraf 0: Topik -1 | -1_presiden_partai_jakarta_dpr | skor=N/A
#   Teks: Beredar tautan bantuan tunai yang meminta OTP pengguna.
#
#   Paragraf 1: Topik -1 | -1_presiden_partai_jakarta_dpr | skor=N/A
#   Teks: Kementerian mengklarifikasi bahwa tautan tersebut palsu dan meminta warga cek kanal resmi.
#
#   Paragraf 2: Topik -1 | -1_presiden_partai_jakarta_dpr | skor=N/A
#   Teks: Pengguna lain melaporkan modus serupa berujung pada pencurian akun.

# %%
from huggingface_hub import login, HfApi
from google.colab import userdata
import os

# ================= AUTH =================
token = userdata.get("HF_TOKEN")
assert token is not None, "HF_TOKEN tidak ditemukan di Colab Secrets"

login(token=token)
os.environ["HF_TOKEN"] = token

api = HfApi()

# ================= PATH =================
INDOBERT_DIR = "/content/indobert_hoax_model_v3"
BERTOPIC_DIR = "/content/bertopic_model_v3"

repo_indobert = "fjrmhri/deteksi_hoaks_indobert"
repo_bertopic = "fjrmhri/deteksi_hoaks_bertopic"

# ================= VALIDASI PATH =================
assert os.path.exists(INDOBERT_DIR), "Folder IndoBERT tidak ditemukan!"
assert os.path.exists(BERTOPIC_DIR), "Folder BERTopic tidak ditemukan!"

print("Isi IndoBERT:", os.listdir(INDOBERT_DIR))
print("Isi BERTopic:", os.listdir(BERTOPIC_DIR))

# ================= CREATE REPO =================
api.create_repo(repo_id=repo_indobert, repo_type="model", exist_ok=True)
api.create_repo(repo_id=repo_bertopic, repo_type="model", exist_ok=True)

# ================= UPLOAD (FORCE-LIKE) =================
print(f"\n[UPLOAD] IndoBERT (force overwrite)...")
api.upload_folder(
    folder_path=INDOBERT_DIR,
    repo_id=repo_indobert,
    repo_type="model",
    delete_patterns="*",
    commit_message="Force update IndoBERT model"
)

print(f"\n[UPLOAD] BERTopic (force overwrite)...")
api.upload_folder(
    folder_path=BERTOPIC_DIR,
    repo_id=repo_bertopic,
    repo_type="model",
    delete_patterns="*",
    commit_message="Force update BERTopic model"
)

print("\n✅ Semua folder berhasil di-upload (mode force overwrite)!")
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# WARNING:huggingface_hub._login:Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# Isi IndoBERT: ['config.json', 'model.safetensors', 'tokenizer.json', 'checkpoint-3507', 'checkpoint-2338', 'tokenizer_config.json', 'inference_config.json']
# Isi BERTopic: ['config.json', 'topic_embeddings.safetensors', 'topics.json']
#
# [UPLOAD] IndoBERT (force overwrite)...
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#   ...kpoint-2338/rng_state.pth: 100%|##########| 14.6kB / 14.6kB
#   ...checkpoint-2338/scaler.pt: 100%|##########| 1.38kB / 1.38kB
#   ...ckpoint-2338/scheduler.pt: 100%|##########| 1.47kB / 1.47kB
#   ...nt-2338/training_args.bin: 100%|##########| 5.20kB / 5.20kB
#   ...checkpoint-3507/scaler.pt: 100%|##########| 1.38kB / 1.38kB
#   ...kpoint-3507/rng_state.pth: 100%|##########| 14.6kB / 14.6kB
#   ...ckpoint-3507/scheduler.pt: 100%|##########| 1.47kB / 1.47kB
#   ...nt-3507/training_args.bin: 100%|##########| 5.20kB / 5.20kB
#   ...odel_v3/model.safetensors:   9%|9         | 39.9MB /  442MB
#   ...nt-3507/model.safetensors:   7%|7         | 32.0MB /  442MB
# No files have been modified since last commit. Skipping to prevent empty commit.
# WARNING:huggingface_hub.hf_api:No files have been modified since last commit. Skipping to prevent empty commit.
# [UPLOAD] BERTopic (force overwrite)...
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#   ...ic_embeddings.safetensors: 100%|##########|  939kB /  939kB
# ✅ Semua folder berhasil di-upload (mode force overwrite)!

# %%
import os

def print_tree(start_path, prefix=""):
    if not os.path.exists(start_path):
        print(f"❌ Path tidak ditemukan: {start_path}")
        return

    files = sorted(os.listdir(start_path))

    for i, name in enumerate(files):
        path = os.path.join(start_path, name)
        connector = "└── " if i == len(files) - 1 else "├── "

        print(prefix + connector + name)

        if os.path.isdir(path):
            extension = "    " if i == len(files) - 1 else "│   "
            print_tree(path, prefix + extension)

# ================= RUN =================
print("📂 Struktur IndoBERT:\n")
print(f"/content/indobert_hoax_model_v3")
print_tree("/content/indobert_hoax_model_v3")

print("\n" + "="*50 + "\n")

print("📂 Struktur BERTopic:\n")
print(f"/content/bertopic_model_v3")
print_tree("/content/bertopic_model_v3")
# Out:
# 📂 Struktur IndoBERT:
#
# /content/indobert_hoax_model_v3
# ├── checkpoint-2338
# │   ├── config.json
# │   ├── model.safetensors
# │   ├── optimizer.pt
# │   ├── rng_state.pth
# │   ├── scaler.pt
# │   ├── scheduler.pt
# │   ├── tokenizer.json
# │   ├── tokenizer_config.json
# │   ├── trainer_state.json
# │   └── training_args.bin
# ├── checkpoint-3507
# │   ├── config.json
# │   ├── model.safetensors
# │   ├── optimizer.pt
# │   ├── rng_state.pth
# │   ├── scaler.pt
# │   ├── scheduler.pt
# │   ├── tokenizer.json
# │   ├── tokenizer_config.json
# │   ├── trainer_state.json
# │   └── training_args.bin
# ├── config.json
# ├── inference_config.json
# ├── model.safetensors
# ├── tokenizer.json
# └── tokenizer_config.json
#
# ==================================================
#
# 📂 Struktur BERTopic:
#
# /content/bertopic_model_v3
# ├── config.json
# ├── topic_embeddings.safetensors
# └── topics.json

# %%
import os
import zipfile
from google.colab import files

# Nama file zip yang akan dibuat
nama_zip = 'hasil_analisis_hoax.zip'

# List untuk menampung file yang akan di-zip
files_to_zip = [f for f in os.listdir('/content') if f.endswith(('.png', '.csv'))]

if files_to_zip:
    with zipfile.ZipFile(nama_zip, 'w') as zipf:
        for file in files_to_zip:
            zipf.write(os.path.join('/content', file), file)
            print(f"Menambahkan ke zip: {file}")

    print(f"\nBerhasil membuat {nama_zip}. Memulai unduhan...")
    # Mendownload file zip ke komputer lokal
    files.download(nama_zip)
else:
    print("Tidak ditemukan file .png atau .csv di direktori /content.")
# Out:
# Menambahkan ke zip: distribusi_topik_bertopic.png
# Menambahkan ke zip: distribusi_dataset.png
# Menambahkan ke zip: roc_curve_validation.png
# Menambahkan ke zip: roc_curve_test.png
# Menambahkan ke zip: confusion_matrix_validation.png
# Menambahkan ke zip: confusion_matrix_test.png
# Menambahkan ke zip: topik_per_label.png
# Menambahkan ke zip: ctfidf_heatmap.png
# Menambahkan ke zip: kalibrasi_threshold_validation.png
# Menambahkan ke zip: kurva_training.png
# Menambahkan ke zip: ctfidf_distribusi_topik.png
# Menambahkan ke zip: evaluasi_ctfidf_topik.csv
#
# Berhasil membuat hasil_analisis_hoax.zip. Memulai unduhan...
